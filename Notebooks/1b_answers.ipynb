# %% [markdown]
# ## Lecture 1b
#
# ## 1. Functions &  Data Visualization: Theory

# %% [markdown]
# **Functions**
#
# In Python, a function is a reusable block of code that performs a specific task when called. Functions are used to organize code into smaller, manageable units, making your programs more readable and maintainable. Here's an explanation of how functions work in Python.
#
# - Function Definition: To create a function, you use the ```def``` keyword followed by the function name and parentheses, which can include parameters. The function definition ends with a colon.
#
#                     Example :
#                          def greet(name):
#                              print("Hello, " + name)
#
# - Function Parameters: Parameters are variables that you can pass to a function. They allow you to provide input to the function, which it can then use in its operations. In the example above, ```name``` is a parameter.
#
# - Function Body: The function body is indented and contains the code that the function executes when called. You can include any valid Python code within the function body.
#
# - Function Call: To use a function, you call it by its name followed by parentheses, and you can pass arguments that match the parameters defined in the function.
#
#                    Example:
#                           greet("Alice")
#
# - Retun Statement: Functions can return values using the return statement. The returned value can be assigned to a variable or used in expressions. The convention is to put a blank line before a function definition as well as after one.
#
#                    Example:
#                         def add(a, b):
#                             return a + b
#
#                         result = add(3, 5)   # Result will be 8
#
#
# **Data Visualization Works in Python**
#
# In Python, data visualization is the graphical representation of data to help users understand, analyze, and derive insights from complex datasets. Python offers several libraries, with Matplotlib and Seaborn being popular choices, to create various types of visualizations. Here's an explanation of how data visualization works in Python:
#
# - Importing Libraries: To get started with data visualization in Python, you typically import relevant libraries, such as Maplotlib and Seaborn. These libraries provide functions and tools for creating different types of visualizations.
#
#                     Example:
#                         import matplotlib.pyplot as plt
#                         import seaborn as sns
#
# - Data preparation: Before creating visualizations, you need to prepare your data. Data can be sourced from various places, such as csv files, databases, or generated programmatically. Ensure the data is structured and organized for effective visualization.
#
#                     Example:
#                         x = [1,2,3,4,5]
#                         y = [10,15,13,18,20]
#
# - Creating Visualizations: You can create various types of visualizations, such as line charts, bar plots, scatter plots, and more, to represent data in a meaning way. These libraries provide methods for plotting data using a range of customizable options.
#
#                     Example:
#                         plt.plot(x, y)
#                         plt.xlabel('X-axis Label')
#                         plt.ylabel('Y-axis Label')
#                         plt.title('Simple Line Chart')
#                         plt.show()

# %% [markdown]
# ## 1. Functions &  Data Visualization: Exercises

# %% [markdown]
# ### 1.1. Functions

# %% [markdown]
# Q1.1.1. Write a simple "say_hello" function with "Hello World" print statement in it. Call the function later on.

# %%
# A1.1.1.
def say_hello():
    print("Hello, World!")

say_hello()
# Out:
# Hello, World!

# %% [markdown]
# Q1.1.2. Write a function "greet" that passes "name" as parameters.

# %%
# A1.1.2.
def greet(name):
    print("Hello, " + name)

greet("Alice")
# Out:
# Hello, Alice

# %% [markdown]
# Q1.1.3 Write an add_numbers function that takes two numbers as parameters and returns their sum.

# %%
# A1.1.3
def add_numbers(a, b):
    result = a + b + 9
    return result

sum = add_numbers(5, 3)
print("The sum is:", sum)
# Out:
# The sum is: 17

# %% [markdown]
# Q1.1.3 Write a multiply_numbers function that takes two numbers as parameters and returns their multiplication.

# %%
# A1.1.3
def multiply_numbers(a, b):
    result = a * b
    return result

multiply = multiply_numbers(6, 7)
print("The multiplication is:", multiply)
# Out:
# The multiplication is: 42

# %% [markdown]
# Q1.1.4 Write square_numbers function that takes a number as parameters and returns its square.

# %%
# A1.1.4
def square_numbers(a):
    result = a * a
    if result > 37:
        output = 4
    else:
        output = result
    return output

square = square_numbers(6)
print("The Square is:", square)
# Out:
# The Square is: 36

# %% [markdown]
# ### 1.2 Data Visualization

# %% [markdown]
# Draw a simple line chart with two lists

# %%
import matplotlib.pyplot as plt
import seaborn as sns


x = [1,2,3,4,5]
y = [10,15,13,18,20]

plt.plot(x, y)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt. title('Simple Line Chart')
plt.show()

# %% [markdown]
# Draw a bar chart

# %%
import matplotlib.pyplot as plt


#Data
category = ['A', 'B', 'C', 'D']
value = [25, 50, 30, 45]

# Create a bar chart
plt.bar(category, value)

# Add labels and a title

plt.xlabel('Categories')
plt.ylabel('Values')
plt. title('Simple Bar Chart')
plt.show()

# %% [markdown]
# Draw a scatter plot

# %%
import matplotlib.pyplot as plt


#Data
x = [1,2,3,4,5]
y = [10,15, 13, 18, 20]

# Create a bar chart
plt.scatter(x, y)

# Add labels and a title

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt. title('Simple Scatter Chart')
plt.show()

# %% [markdown]
# ### 1.3. Importing data

# %% [markdown]
# Q1.3.1. Download the _Spotify Track Dataset_ from Canvas and save it to a folder of your choice. **IMPORTANT! Make sure to save the file under the name "spotify_dataset".**
# A1.3.1 Once the dataset is saved, upload it to your Google Colab files, using the right most _Upload_ button, as shown in the screenshot below:
#
# ![Screenshot 2023-10-09 at 16.18.58.png](data:image/png;base64,...)

# %% [markdown]
# Q1.3.2. Read in the _Spotify Tracks Dataset_.

# %%
# A1.3.2.
import pandas as pd
import os
spotify_data = pd.read_csv(os.path.join(os.getcwd(), "spotify_dataset.csv"))
spotify_data
# Out:
#         row_number                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %% [markdown]
# ### 1.4. Descriptive Analytics in practice

# %% [markdown]
# Q1.4.1. Use ```describe()```  in the ```spotify_data``` dataset that gets the basic statistical information.

# %%
# A1.4.1.
spotify_data.describe()
# Out:
#           row_number     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %% [markdown]
# Q1.4.2 Use ```count()``` in the ```spotify_data``` dataset that gets the number of values in each row.

# %%
# A1.4.2
spotify_data.count()
# Out:
# row_number          114000
# track_id            114000
# artists             113999
# album_name          113999
# track_name          113999
# popularity          114000
# duration_ms         114000
# explicit            114000
# danceability        114000
# energy              114000
# key                 114000
# loudness            114000
# mode                114000
# speechiness         114000
# acousticness        114000
# instrumentalness    114000
# liveness            114000
# valence             114000
# tempo               114000
# time_signature      114000
# track_genre         114000
# dtype: int64

# %% [markdown]
# Q1.4.3 Use mean() in the spotify_data dataset that gets the mean values of ```tempo``` column.

# %%
# A1.4.3
spotify_data['tempo'].mean()
# Out:
# 122.14783728947369

# %% [markdown]
# Q1.4.4 Use mode() in the spotify_data dataset that gets the most frequent value of ```album_name``` column. N.B.: .mode results in a dataframe that may consist of multiple rows if the most occuring value is not unique.

# %%
# A1.4.4
spotify_data['album_name'].mode()
# Out:
# 0    Alternative Christmas 2022
# Name: album_name, dtype: object

# %% [markdown]
# Q1.4.5 Use max() in the spotify_data dataset that gets the max value of ```popularity``` column.

# %%
#A1.4.5
spotify_data['popularity'].max()
# Out:
# 100

# %% [markdown]
# ## 2. Loops and conditionals: Theory

# %% [markdown]
# In this practical we will learn about:
# - how to use if-statements in Python, also known as conditionals
# - how to use for-loops in Python
# - how to use the `range()` function
# - will apply this to the _Spotify Tracks Dataset_.
#
# **Conditionals**
#
# The ``if`` statement is a conditional statement in Python used to determine whether a block of code will be executed. If the program finds the condition defined in the if statement `True`, it will execute the code block inside the if statement. If the conditional expression results in a `False` value, the statement below will not be executed.
#
# In python, if-statements will always have the following form:
#
# ``if <expr>:
#     <statement>``
#
# In the form shown above:
# - ``<expr>`` is a Boolean expression, that should return either ``TRUE`` or ``FALSE``. This is the conditional that is assessed in order to continue with the lines below.
# - ``<statement>`` is a valid Python statement, which must be indented.
#
# Examples of conditional statements are:
# - ``if x>y:`` ,
# if variable x is larger than variable y
# - ``if a==b:`` ,
# if variable a is equal to variable b
# - ``if v in [1,2,3,4,5]:`` ,
# if variable v is in a list with the numbers 1-5
# - ``if w != 6:`` ,
# if variable w is not equal to the value 6
#
# Note that the syntax for 'is equal to' is `==`in Python, and the syntax for 'is not equal to' is `!=`.
#
# In addition to the `if` statement above, Python also allows you to define an `else` statement. This will have the following form:
#
# ``if <expr>:
#       <statement 1>
#   else:
#       <statement 2>``
#
# If the conditional expression `<expr>` will result in a `True` value, `<statement 1>` will be executed. If `<expr>` will be `False`, the programme will continue with `<statement 2>`. Adding an `else` statement to your code will therefore give you the opportunity to tell the programme what it has to do in the other cases (if they appear). We will show you practical examples in the exercises.
#
# **For loops**
#
# A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string). With the for loop we can execute a set of statements, once for each item in a list, tuple, set etc. This for loop can look as follows:
#
# ``for i in <list>:
#     <statement>``
#
# The new variable ``i`` will take every value in the ``<list>`` or other type of sequence. For each value, the ``<statement>`` below is executed. This makes it possible to execute the statement multiple times automatically, without the need for the same lines of code. With the example exercises below, you can practice using the for loop.
#
# Examples of conditional statements are:
# - ``for i in [0,1,2,3,4,5]:`` ,
# where the newly created variable ``i`` will take the value ``0`` in the first loop, and execute the statement below. After that, ``i`` will be equal to ``1`` and execute the same statement, and so on.
# - ``for name in ['Flora','Jacques','Ruud','Krishna','Siham','Lotte']`` ,
# where the newly created variable ``name`` will take the value ``Flora`` in the first loop, and execute the statement below. After that, ``name`` will be equal to ``Jacques`` and execute the same statement, and so on.
#
# **`range()` function**
#
# In Python, there is a predefined function that can help us create a range with ascending or descending integers. It is often used in combination with for loops, such that the iteration variable `i` will take values in this range.
#
# The `range()` function requires a start and a stop value `range(<start>,<stop>)`. It will count from the start value to the stop value, where the stop value will not_ be included! As an example, the `range(0,5)` will give a range as: 0, 1, 2, 3, 4. For more explanation, see https://www.w3schools.com/python/ref_func_range.asp .
#
# The start value is optional, so if you only use a stop value, the range will start at 0 by default. This means that `range(0,10)` and `range(10)` both give the same results. To show you how the range function works in combination with a for loop, see the examples below.
# ![image.png](attachment:image.png)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for j in range(3,9):
    print(j)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8

# %%
#Without a start value, the range function will take 0 as default start value
print(range(5))
# Out:
# range(0, 5)

# %% [markdown]
# ## 2. Loops and conditionals: Exercises

# %% [markdown]
# ### 2.1. Introduction to conditional statements

# %% [markdown]
# Q2.1.1. Conditional statements always require a Boolean expression, that can take only two values. Which two values can the ``<expr>`` be equal to?

# %% [markdown]
# A2.1.1. ``True`` or ``False``

# %%
#We define six new variables
a=6
b=3
c='P'
d=['W','H','O','A']
e='A'
f=False

# %% [markdown]
# Q2.1.2 Which of these variables is a Boolean expression by itself?

# %% [markdown]
# A2.1.2 Variable ```f```, because it takes the value ``True``

# %% [markdown]
# Q2.1.2 Which of the lines below will result in a valid Boolean expression that can be used in an ``if`` statement? Answer yes or no before running the cells. If it is indeed a Boolean expression, predict the outcome (being `True` or `False`).
# - ``a == b``
# - ``a > b``
# - ``a = b``
# - ``c != e``
# - `e in d`
# - `12.2 > 3.7`
# - `f`
#
# You can check your answers by running the cells below. If the cell returns a `TypeError`, the expression is not a Boolean expression.

# %%
print(a == b)
# Out:
# False

# %%
print(a > b)
# Out:
# True

# %%
print(a = b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-26c0a47b5777> in <cell line: 1>()
# ----> 1 print(a = b)
#
# TypeError: 'a' is an invalid keyword argument for print()

# %%
print(c != e)

# %%
print(e in d)
# Out:
# True

# %%
print(12.2 > 3.7)
# Out:
# True

# %%
print(f)
# Out:
# False

# %% [markdown]
# A2.1.2 Only the expression `a=b` does not result in a Boolean (`True` or `False`). Remember from previous lectures, that a single `=` sign means that you assign the variable `a` a new value. The first and last Boolean expressions were `False`, the others were `True`.

# %% [markdown]
# Let us use one of the Boolean statements above to create an if statement.
#
# Q2.1.3: Can you tell what goes wrong in the conditional statement below? Why does it create an error? Run the cell first, and then resolve the error by altering the code. Use the Error description as a hint for your solution.

# %%
if c!=e:
print('c is not equal to e')
# Out:
#   File "<ipython-input-40-b8f1dd1a6db8>", line 2
#     print('c is not equal to e')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# A2.1.3: The code for the statement is not created with an indent. Note that the lines of code within the if statement (after the `:` should always start with an indentation. This is why Python gives you back an `IndentationError`. Your new code should look like:

# %%
#A2.1.3
if c!=e:
    print('c is not equal to e')
# Out:
# c is not equal to e

# %% [markdown]
# Q2.1.4 Now that you have seen an example, create a conditional statement that prints the letter `T` when variable `b` is equal to 3. Remember to print the string T, see notebook lecture 1.

# %%
#A2.1.4
if b == 3:
    print('T')
# Out:
# T

# %% [markdown]
# Q2.1.5 What will happen if we change the value of `b` to 5? Redefine your value by running the cell below, and then run your lines of code with the conditional statement again.

# %%
b = 5

# %% [markdown]
# A2.1.5 Nothing happens; because the conditional statement is false the statement `print(T)` will not be executed.

# %% [markdown]
# Q2.1.6 Copy your conditional statement above and add two extra lines of code, such that the programme prints an `F` in the cases where `b == 3` is `False`. You can do this in two ways, one using another `if` statement and one using the `else` statement.

# %%
#A2.1.6
if b == 3:
    print('T')
else:
    print('F')

## or
if b == 3:
    print('T')
if b!= 3:
    print('F')
# Out:
# F
# F

# %% [markdown]
# ### 2.2 Introduction to for loops

# %% [markdown]
# We will first define a variable `word_list` as a list with three strings in there.
#
# Q2.2.1 Predict what the lines of code will show, before pressing run. Can you describe what happens?

# %%
word_list = ['First word', 'Second word', 'Third word']
for word in word_list:
    print(word)
# Out:
# First word
# Second word
# Third word

# %% [markdown]
# A2.2.1 The variable `word` takes the (string) value `First word` in the first iteration. Then it proceeds to the statement below, where the current value of `word` is printed. In the next iteration, the variable `word` takes the (string) value `Second word`. Then it proceeds to the statement below again, and prints the current value of `word`. This way, all three values are printed one after the other; one in each iteration.

# %% [markdown]
# Now we want to combine the for loop and the if statement, such that only the last two words from the word list will be printed.
#
# Q.2.2.2 Copy the code above and make sure that only the `Second word` and `Third word` will be printed, by using an if statement.

# %%
# A.2.2.2 version 1
word_list = ['First word', 'Second word', 'Third word']
for word in word_list:
    if word != 'First word':
        print(word)
# Out:
# Second word
# Third word

# %%
## A2.2.2 version 2
word_list = ['First word', 'Second word', 'Third word']
for word in word_list:
    if word in ['Second word','Third word']:
        print(word)
# Out:
# Second word
# Third word

# %% [markdown]
# Q2.2.3 Use a for loop and a range function to print the multiplication table of 8.

# %%
# A2.2.3
for i in range(0,11):
    print(i*8)
# Out:
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 80

# %% [markdown]
# Q2.2.4 Calculate the sum of all numbers from 1 to 28 using a range function and a for loop. Hints:
# - Predefine a counter variable `s=0` before you start with your for loop
# - Create a for loop over the values that you want to add (1-28)
# - Add this number to your counter value `s` each iteration, thus us an addition within your for loop statement (`s = s + ???`)
# - Print the outcome only after all iterations have been executed, thus outside of your for loop.
#
# Remember that your indentation will indicate whether a line is within or outside of your for loop.

# %%
#A2.2.4
s=0
for j in range(3,6):
    s = s+j
print(s)
# Out:
# 12

# %% [markdown]
# ### 2.3. Conditionals and for loops in practice

# %% [markdown]
# Q2.3.1. Make a list of the first five column names in the ```spotify_data``` dataset. Try using the `.columns` function, change the output of this function into a list by using `list(...)` and use the index `[0:5]` as you have learned in previous lectures. Then use a for loop to print them one by one.

# %%
#A2.3.1
#Making a list using the columns() function and indexing:
column_names_index = list(spotify_data.columns)[0:5]
#Printing the column names one by one by using a for loop:
for column_name in column_names_index:
    print(column_name)
# Out:
# row_number
# track_id
# artists
# album_name
# track_name

# %% [markdown]
# Our goal is now to print all the album names that contain the word `Christmas` below each other, using the if statement and the for loop.
#
# As a start, we make a list with all the unique album names that are in the dataset by:
# 1. Select the column `album_name` from the dataset with `spotify_data['album_name']` as you learned in the indexing lecture.
# 2. From this selected column, we remove the NA values by using the formula `.dropna()`. *
# 3. From this selected column without NA values, we take the unique values using the formula `.unique()`.**
# 4. Transform the resulting array to a list such that we can work with it more easily.
#
# This is done in the line of code below. Make sure that you understand these steps one by one.
#
# We now have a list with all unique album names that were part of the dataset.
#
# _________________________________________
#
# \* You might not have learned about this function, but it will remove the missing values from our dataset. Remember that you can always look up what a certain function does on the internet, see: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
#
# \** Look up what the unique function does here: https://numpy.org/doc/stable/reference/generated/numpy.unique.html

# %%
list(spotify_data['album_name'].dropna().unique())
# Out:
# ['Comedy',
#  'Ghost (Acoustic)',
#  'To Begin Again',
#  'Crazy Rich Asians (Original Motion Picture Soundtrack)',
#  'Hold On',
#  'Days I Will Remember',
#  'Is There Anybody Out There?',
#  'We Sing. We Dance. We Steal Things.',
#  'Hunger',
#  'Episode',
#  'Love Is a Four Letter Word',
#  'Solo',
#  'Bad Liar',
#  'Hold On (Remix)',
#  'The Boy Who Never',
#  'ily (i love you baby)',
#  'At My Worst',
#  'Cover Sessions, Vol. 4',
#  'Cover Sessions, Vol. 3',
#  'Is There Anybody Out There? - Track by Track Commentary',
#  'Coffee Moment',
#  'Human - Best Adult Pop Tunes',
#  'Mellow Adult Pop',
#  'Holly Jolly Christmas',
#  'Feeling Good - Adult Pop Favorites',
#  'Christmas Time',
#  'Perfect Christmas Hits',
#  'Merry Christmas',
#  'Christmas Music - Holiday Hits',
#  'Christmas Country Songs 2022',
#  "Mellow Bars R'n'B",
#  'Chill Christmas Dinner',
#  'rainy day indie',
#  'sadsadchristmas',
#  'Mega Hits Autumn/Fall 2022',
#  'Country Car Hits',
# ...

# %% [markdown]
# Q2.3.2
#
# A) Define a variable album_list that is equal to the list created in the cell above. You can copy and paste this line to define the variable.
#
# B) Then use a formula you learned before to determine the amount of unique album names that we have here.

# %%
#A2.3.2
#A)
album_list = list(spotify_data['album_name'].dropna().unique())
#B)
len(album_list)
# Out:
# 46589

# %% [markdown]
# Q2.3.3 Use a for loop and an if statement to print the album names that contain the word `Christmas`.
# - Use a for loop with the iteration variable `album_name`, that takes all values in the `album_list`
# - Then us an if statement, with the following Boolean expression: `'Christmas' in album_name`. This expression checks if the string `Christmas` is part of the string that `album_name` has in the current iteration.

# %%
#A2.3.3
for album_name in album_list:
    if 'Christmas' in album_name:
        print(album_name)
# Out:
# Holly Jolly Christmas
# Christmas Time
# Perfect Christmas Hits
# Merry Christmas
# Christmas Music - Holiday Hits
# Christmas Country Songs 2022
# Chill Christmas Dinner
# Slow Christmas Songs 2022
# Lonely Christmas 2022
# Alternative Christmas 2022
# Acoustic Christmas Campfire
# Christmas Faves 2022
# Christmas Vibes But Not Christmas Songs
# Have Yourself a Merry Little Christmas
# Christmas Island
# Last Christmas
# Happy Country Christmas
# A Johnnyswim Christmas
# 100 Greatest Christmas Songs Ever (Top Xmas Pop Hits)
# Rock n Roll Christmas
# Home For Christmas 2022
# Home At Christmas
# Christmas Rock 2022
# Emo Christmas 2022
# Christmas Songs 2022
# Pop Christmas 2022
# Santa's Christmas List
# Christmas Dinner
# Christmas Eve At Home
# Classical Christmas
# Classical Christmas 2022
# Calm Christmas
# 70s Christmas Party
# World's Best Christmas Playlist
# Rockin' Around The Christmas Tree 2022
# Cuddle Up Christmas
# All I want For Christmas Is Music
# ...

# %% [markdown]
# If we want to count the number of album names that contain the word `Christmas`, we can use a counter variable `n` that counts the number of times we arrive within the if statement.
#
# Q2.3.4 Create this counter in the following way:
# 1. Copy your code used above
# 2. Above the for loop, define a variable `n=0`. Your counter will start at 0.
# 3. Every time the programme arrives within the if statement (and thus every time the word `Christmas` is part of our album name), we want to add one to our counter. Therefore, you can create an additional statement line in this if loop `n=n+1`.
# 4. We only want to print the outcome of the counter at the end, after all album names in the `album_list` have passed. Use a print statement to print the final counter value. Make sure to adapt the indentation such that the `n` is not part of the for loop nor the if statement.
#
# What is the number of unique albums in the Spotify dataset that contains the word Christmas?

# %%
#A2.3.4
n=0
for album_name in album_list:
    if 'Christmas' in album_name:
        print(album_name)
        n=n+1
print(n)
# Out:
# Holly Jolly Christmas
# Christmas Time
# Perfect Christmas Hits
# Merry Christmas
# Christmas Music - Holiday Hits
# Christmas Country Songs 2022
# Chill Christmas Dinner
# Slow Christmas Songs 2022
# Lonely Christmas 2022
# Alternative Christmas 2022
# Acoustic Christmas Campfire
# Christmas Faves 2022
# Christmas Vibes But Not Christmas Songs
# Have Yourself a Merry Little Christmas
# Christmas Island
# Last Christmas
# Happy Country Christmas
# A Johnnyswim Christmas
# 100 Greatest Christmas Songs Ever (Top Xmas Pop Hits)
# Rock n Roll Christmas
# Home For Christmas 2022
# Home At Christmas
# Christmas Rock 2022
# Emo Christmas 2022
# Christmas Songs 2022
# Pop Christmas 2022
# Santa's Christmas List
# Christmas Dinner
# Christmas Eve At Home
# Classical Christmas
# Classical Christmas 2022
# Calm Christmas
# 70s Christmas Party
# World's Best Christmas Playlist
# Rockin' Around The Christmas Tree 2022
# Cuddle Up Christmas
# All I want For Christmas Is Music
# ...

# %% [markdown]
# A2.3.4 Thus, the number of unique albums with the word Christmas in there is equal to **138**.

# %% [markdown]
# Q2.3.5 Can you use similar code to determine the number of songs that have a danceability score larger than 0.8? Use the hints below.
# - First, make a list with all the danceability scores that are in the spotify dataset using the column indexing (use `[]` with the correct column name)
# - Initialize a counter variable `n=0`
# - Then, use a for loop and an if statement, such that only in cases with a danceability score > 0.8 the statement will be executed to increase the counter with +1
# - Print the counter in the end, after all iterations have been executed

# %%
#A2.3.5
n=0
d_scores = list(spotify_data['danceability'])
for d in d_scores:
    if d>0.8:
        n=n+1
print(n)
# Out:
# 8768

# %% [markdown]
# A2.3.5 Thus there are **8768** songs in the dataset with a danceability score larger than 0.8.

# %% [markdown]
# Q2.3.6 In the same way, count the number of songs with a tempo above 100 beats per minute.

# %%
#A2.3.6
n=0
tempo_scores = list(spotify_data['tempo'])
for tempo in tempo_scores:
    if tempo>100:
        n=n+1
print(n)
# Out:
# 84119

# %% [markdown]
# A2.3.6 Thus there are **84119** songs in the dataset with a tempo higher than 100 BPM.

# %% [markdown]
# Q2.3.7 What percentage of the total dataset is upbeat, above the value of 100 BPM? Hint: use the `len()` or `.shape` function to determine the amount of rows of the total dataset `spotify_data`.

# %%
#A2.3.7

# To calculate the percentage, divide this amount by the total number of rows
print(n/len(spotify_data)*100)

#or

print(n/spotify_data.shape[0]*100)
# Out:
# 73.78859649122808
# 73.78859649122808

# %% [markdown]
# A2.4.7 Thus **73.8%** of the songs has a higher tempo than 100 BPM.
