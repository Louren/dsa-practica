# %% [markdown]
# ### Lecture 1a: Introduction
# Notebook Lecture 1a
# ***

# %% [markdown]
# ## 1. Basics: Exercises

# %% [markdown]
# ### 1.1. Data types

# %% [markdown]
# Q1.1.1 Can you figure out the data types of the three variables?

# %%
# Let's create three variables
variable_1 = "Rob"
variable_2 = 5
variable_3 = 7.1

# %% [markdown]
# A1.1.1 ```variable_1``` is a string, ```variable_2``` is an integer, ```variable_3``` is a float. You can check this by typing ```type(variable_1)``` if you want to know this for ```variable_1``` (or ```variable_2```, or ```variable_3``` for the other variable).

# %% [markdown]
# A1.1.1: (double click to edit)

# %% [markdown]
# Q1.1.2. Can you figure out the data types of the three variables?

# %%
# Let's create three variables
variable_1 = 5
variable_2 = "7.1"
variable_3 = 'Rob'

# %% [markdown]
# A1.1.2: ...

# %% [markdown]
# A1.1.2. ```variable_1``` is an integer, ```variable_2``` is a string, ```variable_3``` is also a string. You can check this by typing ```type(variable_1)``` if you want to know this for ```variable_1``` (or ```variable_2```, or ```variable_3``` for the other variable).

# %% [markdown]
# ### 1.2. Operators

# %% [markdown]
# Let's try to perform some operations on the data.

# %%
# Let's create six variables
q3_1 = 5
q3_2 = 7.1
q3_3 = "Rob"
q3_4 = 28.7
q3_5 = 300
q3_6 = 5

# %% [markdown]
# Q1.2.1. Create a new variable called new_variable and assign it to the sum of ```q3_1``` and ```q3_2```.

# %%
# A1.2.1.
new_variable = q3_1 + q3_2

# %% [markdown]
# Q1.2.2. Print out the value of ```new_variable``` on the screen.

# %%
# A1.2.2.
print(new_variable)
# Out:
# 12.1

# %% [markdown]
# Q1.2.3. Create a new variable called ```new_variable_2``` and assign it to the sum of ```q3_2``` and ```q3_3```.

# %%
# A1.2.3.
#new_variable_2 = q3_2 + q3_3

# %% [markdown]
# Q1.2.4. This does not work. Take some time to read the error message, and explain why this does not work.

# %% [markdown]
# #Answer: A1.2.4. It doesn't work because you can't add a float and a string. We did find out in Q3.1 that we can add integers and floats, but we can't add floats with strings, nor can we add integers with strings.

# %% [markdown]
# Q1.2.5. Create a new variable called x that is the division of ```q3_4``` by ```q3_5```.

# %%
# A1.2.5.
x = q3_4 / q3_5

# %% [markdown]
# Q1.2.6. Print out the value of ```x```. The value should be ```0.09566...```

# %%
# A1.2.6.
print(x)
# Out:
# 0.09566666666666666

# %% [markdown]
# Q1.2.7. What do you think is the data type if ```x```? Check if you're correct by applying the type function.

# %%
# A1.2.7.
type(x)
# Out:
# float

# %% [markdown]
# Q1.2.8. Create a variable ```y``` that is ```q3_6``` mod ```q3_5```. Print ```y``` on the screen (should be ```5```).

# %%
# A1.2.8.
y = q3_6 % q3_5
print(y)
# Out:
# 5

# %% [markdown]
# Q1.2.9. Create a variable ```z``` by dividing ```q3_5``` by ```q3_4``` using floor division. Print ```z``` on the screen (should be ```10.0```).

# %%
# A1.2.9.
z = q3_5 // q3_4
print(z)
# Out:
# 10.0

# %% [markdown]
# Q1.2.10. Assign the value of ```10``` to variable ```x```, and assign the value ```11``` to variable ```y```. Check if they are equal to each other (which of course they're not, so Python should output ```False```).

# %%
# A1.2.10.
x = 10
y = 11
x == y
# Out:
# False

# %% [markdown]
# Q1.2.11. Now check if ```y``` is greater than ```x```. Python should output ```True```.

# %%
# A1.2.11.
y > x
# Out:
# True

# %% [markdown]
# Q1.2.12. Overwrite the value of ```y``` to ```10```, and check if ```x``` equals ```y```.

# %%
# A1.2.12.
y = 10
x == y
# Out:
# True

# %% [markdown]
# Q1.2.13. Now test if x is greater than or equal to y, and if x is smaller than or equal to y. Print out both results on screen. What happens if you don't print them on screen?

# %%
# A1.2.13.
print(x >= y)
print(x <= y)

# If you don't print both statements on the screen, Python will only output the last results (so, only the
# True statement that relates to x <= y)
# Out:
# True
# True

# %% [markdown]
# ## 2. Datasets & Indexing: Exercises

# %% [markdown]
# We will make use of the _DigiJazz GL Dataset_, which contains all GL Transactions for DigiJazz for one year, obtained from their Auditfile.
#
# ## Introduction DigiJazz
# [DigiJazz.nl](DigiJazz.nl) is an internationally recognized e-commerce company specializing in the online sale of jazz music. It was founded in 2015 by Dean Mus and Rob Tone. The company provides a 24/7 platform for customers worldwide to download jazz music.
#
# The start-up has been extremely successful and has experienced rapid growth ever since. In 2017, DigiJazz also began selling vinyl records. This was a great success, as many jazz enthusiasts appreciate the nostalgia of vinyl. Consequently, revenue has significantly increased annually since 2018.
#
# Refer to the DigiJazz introduction on Canvas for more information about the company and the dataset.

# %% [markdown]
# ### 2.1. Importing a dataset

# %% [markdown]
# Q2.1.1. Download the _DigiJazz GL Dataset_ from Canvas and save it to a folder of your choice. **IMPORTANT! Make sure to save the file under the name `transactions.xlsx`.**
#
# A2.1.1 Once the dataset is saved, upload it to your Google Colab files, using the right most _Upload_ button, as shown in the screenshot below:
#
# <Mark>Maybe update the screenshot for new filename</Mark>
#
# ![Screenshot 2023-10-09 at 16.18.58.png](data:image/png;base64,...)

# %% [markdown]
# Q2.1.2. Read in the _DigiJazz GL Dataset_.

# %%
#A2.1.2.
import pandas as pd
import os
# Path needs to be adjusted to the location of the file - Louren to set this to proper path for Colab
gl_data = pd.read_excel(os.path.join(os.getcwd(), "../../GL Generate/transactions.xlsx"), sheet_name="GLData");
gl_data
# Out:
#              Date   Period                                        Description  \
# 0      2024-01-01  2024-01                   Accrual for Rent - Landlord Inc.
# 1      2024-01-01  2024-01                   Accrual for Rent - Landlord Inc.
# 2      2024-01-01  2024-01             Accrual for Water bill - Waternet B.V.
# 3      2024-01-01  2024-01             Accrual for Water bill - Waternet B.V.
# 4      2024-01-01  2024-01  Accrual for Statutory Audit - Tech Audit Firm ...
# ...           ...      ...                                                ...
# 967967 2025-02-18  2025-02                                Payment to Supplier
# 967968 2025-02-21  2025-02                                Payment to Supplier
# 967969 2025-02-21  2025-02                                Payment to Supplier
# 967970 2025-02-23  2025-02                                Payment to Supplier
# 967971 2025-02-23  2025-02                                Payment to Supplier
#
#        JournalCode      JournalDesc JournalType    Booknr  AccountCode  \
# 0               GJ  General Journal     General  GJ069234         4100
# 1               GJ  General Journal     General  GJ069234         1950
# 2               GJ  General Journal     General  GJ069246         4201
# 3               GJ  General Journal     General  GJ069246         1950
# 4               GJ  General Journal     General  GJ069258         4200
# ...            ...              ...         ...       ...          ...
# 967967          CJ     Cash Journal        Cash  CJ196283         1100
# 967968          CJ     Cash Journal        Cash  CJ196199         1300
# 967969          CJ     Cash Journal        Cash  CJ196199         1100
# 967970          CJ     Cash Journal        Cash  CJ195827         1300
# 967971          CJ     Cash Journal        Cash  CJ195827         1100
#
#                       AccountDesc AccountType Debit/Credit    Amount  \
# 0                    Rent Expense     Expense        Debit   1200.00
# 1                Accruals Payable   Liability       Credit   1200.00
# 2                       Utilities     Expense        Debit     80.00
# 3                Accruals Payable   Liability       Credit     80.00
# 4       Accounting and Audit Fees     Expense        Debit  10000.00
# ...                           ...         ...          ...       ...
# 967967          Bank account *313       Asset       Credit   2493.65
# 967968                  Creditors   Liability        Debit    165.19
# 967969          Bank account *313       Asset       Credit    165.19
# 967970                  Creditors   Liability        Debit    143.46
# 967971          Bank account *313       Asset       Credit    143.46
#
#         Product ID             User Relation_id   Relation_name  \
# 0              NaN              NaN         NaN             NaN
# 1              NaN              NaN  SUPL000001   Landlord Inc.
# 2              NaN              NaN         NaN             NaN
# 3              NaN              NaN  SUPL000001   Waternet B.V.
# 4              NaN              NaN         NaN             NaN
# ...            ...              ...         ...             ...
# 967967         NaN     hafsa_bouali         NaN             NaN
# 967968         NaN          dbadmin  SUPL000008           Exact
# 967969         NaN          dbadmin         NaN             NaN
# 967970         NaN  leon_vandermeer  SUPL000094  Schiphol Group
# 967971         NaN  leon_vandermeer         NaN             NaN
#
#                                Account
# 0                    4100 Rent Expense
# 1                1950 Accruals Payable
# 2                       4201 Utilities
# 3                1950 Accruals Payable
# 4       4200 Accounting and Audit Fees
# ...                                ...
# 967967          1100 Bank account *313
# 967968                  1300 Creditors
# 967969          1100 Bank account *313
# 967970                  1300 Creditors
# 967971          1100 Bank account *313
#
# [967972 rows x 17 columns]

# %% [markdown]
# ### 2.2. Descriptives

# %% [markdown]
# Q2.2.1. Provide descriptive statistics for each column of the _GL Data_ dataset using the function `describe()`. Why are the columns ```Description```, ```JournalDesc```, ```AccountType```, and ```Relation_name``` not included in this overview?

# %% [markdown]
# A2.2.1. The ```describe()``` function only provides continuous descriptive statistics. This is not possible when the column contains categorical data.

# %%
gl_data.describe()
# Out:
#                                 Date    AccountCode         Amount  \
# count                         967972  967972.000000  967972.000000
# mean   2024-07-02 04:32:15.695660544    2678.238591      47.834209
# min              2024-01-01 00:00:00    1100.000000       0.100000
# 25%              2024-04-02 00:00:00    1100.000000      10.220000
# 50%              2024-07-02 00:00:00    1100.000000      24.200000
# 75%              2024-10-01 00:00:00    2110.000000      59.890000
# max              2025-02-23 00:00:00    8001.000000  120000.000000
# std                              NaN    2682.086564     402.428062
#
#           Product ID
# count  192520.000000
# mean     1498.665074
# min      1000.000000
# 25%      1000.000000
# 50%      1000.000000
# 75%      2000.000000
# max      2000.000000
# std       499.999517

# %% [markdown]
# Q2.2.2. Which column has the highest maximum value?

# %% [markdown]
# A2.2.2. The ```duration_ms``` has the highest maximum value. This information can be found in the table made using the ```describe()``` function.

# %% [markdown]
# Q2.2.3. There is a column that is named ```energy```. Which index does this column have?

# %% [markdown]
# A2.2.3. The column index of the column ```AccountDesc``` is 8. You can figure this out by manually counting the number of columns from 0. Alternatively, you can access the columns of the ```gl_data``` DataFrame using ```columns``` and then accessing the index number using ```get_loc()```.

# %%
gl_data.columns.get_loc("AccountDesc")
# Out:
# 8

# %% [markdown]
# Q2.2.4. Show the first six rows of the ```spotify_data``` dataset.

# %%
#A2.2.4.
df = gl_data.head(6)
#df = spotify_data[['row_number','popularity','duration_ms','danceability']].head(6)
df
# Out:
#         Date   Period                                        Description  \
# 0 2024-01-01  2024-01                   Accrual for Rent - Landlord Inc.
# 1 2024-01-01  2024-01                   Accrual for Rent - Landlord Inc.
# 2 2024-01-01  2024-01             Accrual for Water bill - Waternet B.V.
# 3 2024-01-01  2024-01             Accrual for Water bill - Waternet B.V.
# 4 2024-01-01  2024-01  Accrual for Statutory Audit - Tech Audit Firm ...
# 5 2024-01-01  2024-01  Accrual for Statutory Audit - Tech Audit Firm ...
#
#   JournalCode      JournalDesc JournalType    Booknr  AccountCode  \
# 0          GJ  General Journal     General  GJ069234         4100
# 1          GJ  General Journal     General  GJ069234         1950
# 2          GJ  General Journal     General  GJ069246         4201
# 3          GJ  General Journal     General  GJ069246         1950
# 4          GJ  General Journal     General  GJ069258         4200
# 5          GJ  General Journal     General  GJ069258         1950
#
#                  AccountDesc AccountType Debit/Credit   Amount  Product ID  \
# 0               Rent Expense     Expense        Debit   1200.0         NaN
# 1           Accruals Payable   Liability       Credit   1200.0         NaN
# 2                  Utilities     Expense        Debit     80.0         NaN
# 3           Accruals Payable   Liability       Credit     80.0         NaN
# 4  Accounting and Audit Fees     Expense        Debit  10000.0         NaN
# 5           Accruals Payable   Liability       Credit  10000.0         NaN
#
#   User Relation_id           Relation_name                         Account
# 0  NaN         NaN                     NaN               4100 Rent Expense
# 1  NaN  SUPL000001           Landlord Inc.           1950 Accruals Payable
# 2  NaN         NaN                     NaN                  4201 Utilities
# 3  NaN  SUPL000001           Waternet B.V.           1950 Accruals Payable
# 4  NaN         NaN                     NaN  4200 Accounting and Audit Fees
# 5  NaN  SUPL000001  Tech Audit Firm X B.V.           1950 Accruals Payable

# %% [markdown]
# Q2.2.5. Show the last 15 rows of the ```spotify_data``` dataset.

# %%
# A.2.2.5.
gl_data.tail(n=15)
# Out:
#              Date   Period          Description JournalCode   JournalDesc  \
# 967957 2025-02-12  2025-02  Payment to Supplier          CJ  Cash Journal
# 967958 2025-02-14  2025-02  Payment to Supplier          CJ  Cash Journal
# 967959 2025-02-14  2025-02  Payment to Supplier          CJ  Cash Journal
# 967960 2025-02-14  2025-02  Payment to Supplier          CJ  Cash Journal
# 967961 2025-02-14  2025-02  Payment to Supplier          CJ  Cash Journal
# 967962 2025-02-15  2025-02  Payment to Supplier          CJ  Cash Journal
# 967963 2025-02-15  2025-02  Payment to Supplier          CJ  Cash Journal
# 967964 2025-02-16  2025-02  Payment to Supplier          CJ  Cash Journal
# 967965 2025-02-16  2025-02  Payment to Supplier          CJ  Cash Journal
# 967966 2025-02-18  2025-02  Payment to Supplier          CJ  Cash Journal
# 967967 2025-02-18  2025-02  Payment to Supplier          CJ  Cash Journal
# 967968 2025-02-21  2025-02  Payment to Supplier          CJ  Cash Journal
# 967969 2025-02-21  2025-02  Payment to Supplier          CJ  Cash Journal
# 967970 2025-02-23  2025-02  Payment to Supplier          CJ  Cash Journal
# 967971 2025-02-23  2025-02  Payment to Supplier          CJ  Cash Journal
#
#        JournalType    Booknr  AccountCode        AccountDesc AccountType  \
# 967957        Cash  CJ196570         1100  Bank account *313       Asset
# 967958        Cash  CJ195825         1300          Creditors   Liability
# 967959        Cash  CJ195825         1100  Bank account *313       Asset
# 967960        Cash  CJ196550         1300          Creditors   Liability
# 967961        Cash  CJ196550         1100  Bank account *313       Asset
# 967962        Cash  CJ195702         1300          Creditors   Liability
# 967963        Cash  CJ195702         1100  Bank account *313       Asset
# 967964        Cash  CJ195819         1300          Creditors   Liability
# 967965        Cash  CJ195819         1100  Bank account *313       Asset
# 967966        Cash  CJ196283         1300          Creditors   Liability
# 967967        Cash  CJ196283         1100  Bank account *313       Asset
# 967968        Cash  CJ196199         1300          Creditors   Liability
# 967969        Cash  CJ196199         1100  Bank account *313       Asset
# 967970        Cash  CJ195827         1300          Creditors   Liability
# 967971        Cash  CJ195827         1100  Bank account *313       Asset
#
#        Debit/Credit   Amount  Product ID               User Relation_id  \
# 967957       Credit   145.62         NaN        yusuf_dirik         NaN
# 967958        Debit   404.68         NaN  daan_vandenheuvel  SUPL000026
# 967959       Credit   404.68         NaN  daan_vandenheuvel         NaN
# 967960        Debit  2238.51         NaN       hafsa_bouali  SUPL000056
# 967961       Credit  2238.51         NaN       hafsa_bouali         NaN
# 967962        Debit  1172.08         NaN       hafsa_bouali  SUPL000057
# 967963       Credit  1172.08         NaN       hafsa_bouali         NaN
# 967964        Debit  8315.01         NaN            dbadmin  SUPL000097
# 967965       Credit  8315.01         NaN            dbadmin         NaN
# 967966        Debit  2493.65         NaN       hafsa_bouali  SUPL000017
# 967967       Credit  2493.65         NaN       hafsa_bouali         NaN
# 967968        Debit   165.19         NaN            dbadmin  SUPL000008
# 967969       Credit   165.19         NaN            dbadmin         NaN
# 967970        Debit   143.46         NaN    leon_vandermeer  SUPL000094
# 967971       Credit   143.46         NaN    leon_vandermeer         NaN
#
#               Relation_name                 Account
# 967957                  NaN  1100 Bank account *313
# 967958    Tarkett Nederland          1300 Creditors
# 967959                  NaN  1100 Bank account *313
# 967960              Euretco          1300 Creditors
# 967961                  NaN  1100 Bank account *313
# 967962           NMC Health          1300 Creditors
# 967963                  NaN  1100 Bank account *313
# 967964  Toshiba Corporation          1300 Creditors
# 967965                  NaN  1100 Bank account *313
# 967966         Pon Holdings          1300 Creditors
# 967967                  NaN  1100 Bank account *313
# 967968                Exact          1300 Creditors
# 967969                  NaN  1100 Bank account *313
# 967970       Schiphol Group          1300 Creditors
# 967971                  NaN  1100 Bank account *313

# %% [markdown]
# ### 2.3. Indexing

# %% [markdown]
# 2.3.1. Select all values within the column ```AccountDesc``` by using _loc_.

# %%
# A2.3.1.
gl_data.loc[:,"AccountDesc"]
# Out:
# 0                      Rent Expense
# 1                  Accruals Payable
# 2                         Utilities
# 3                  Accruals Payable
# 4         Accounting and Audit Fees
#                     ...
# 967967            Bank account *313
# 967968                    Creditors
# 967969            Bank account *313
# 967970                    Creditors
# 967971            Bank account *313
# Name: AccountDesc, Length: 967972, dtype: object

# %% [markdown]
# Q2.3.2. Select all values within the column ```energy``` by using _iloc_.

# %%
# A2.3.2.
gl_data.iloc[:,8]
# Out:
# 0                      Rent Expense
# 1                  Accruals Payable
# 2                         Utilities
# 3                  Accruals Payable
# 4         Accounting and Audit Fees
#                     ...
# 967967            Bank account *313
# 967968                    Creditors
# 967969            Bank account *313
# 967970                    Creditors
# 967971            Bank account *313
# Name: AccountDesc, Length: 967972, dtype: object

# %% [markdown]
# Q2.3.3. Select the fifth and sixth row of the column ```Amount```.

# %%
# A2.3.3.
gl_data.loc[4:5,"Amount"]
# Out:
# 4    10000.0
# 5    10000.0
# Name: Amount, dtype: float64

# %% [markdown]
# Q2.3.4. Select the fifth and sixth row of the columns ```Account``` and ```Amount``` and `Relation_name`.

# %%
# A2.3.4.
gl_data.loc[4:5,["Account","Amount","Relation_name"]]
# Out:
#                           Account   Amount           Relation_name
# 4  4200 Accounting and Audit Fees  10000.0                     NaN
# 5           1950 Accruals Payable  10000.0  Tech Audit Firm X B.V.

# %% [markdown]
# ### 2.4. Conditional indexing

# %% [markdown]
# You can use operators to specify values that are in line with certain conditions. More specifically, you can type something along the lines of ```df.loc[:,'x']>1``` to get a ```True``` for all the rows of column ```x``` that are higher than 1 and a ```False``` for all the others.
#
# You can use those Boolean values to show these rows by typing ```df.loc[df.loc[:,'x']>1,'x']```. You could also do this in two steps by first creating an object that, for example, is called _row_indices_, and then using that object. So,
# - ```row_indices = df.loc[:,'x']>1```
# - ```df.loc[row_indices,'x']```

# %% [markdown]
# Q2.4.1. Select the rows that have a Debit amount

# %%
# A2.4.1.
print("Method 1 (using loc):")
gl_data.loc[gl_data.loc[:,"Debit/Credit"] == "Debit","Amount"]
# Out:
# Method 1 (using loc):
# 0          1200.00
# 2            80.00
# 4         10000.00
# 6         30000.00
# 7          2400.00
#             ...
# 967962     1172.08
# 967964     8315.01
# 967966     2493.65
# 967968      165.19
# 967970      143.46
# Name: Amount, Length: 388238, dtype: float64

# %%
# A2.4.1.
print("Method 2 (using loc, with an extra step for readability):")
rows_of_interest = gl_data.loc[:,"Debit/Credit"] == "Debit"
gl_data.loc[rows_of_interest,"Amount"]
# Out:
# Method 2 (using loc, with an extra step for readability):
# 0          1200.00
# 2            80.00
# 4         10000.00
# 6         30000.00
# 7          2400.00
#             ...
# 967962     1172.08
# 967964     8315.01
# 967966     2493.65
# 967968      165.19
# 967970      143.46
# Name: Amount, Length: 388238, dtype: float64

# %% [markdown]
# You can create _subsets_ of data in a similar way as shown above, but by _not_ specifying a column. In this case, the ```loc[]``` function is no longer needed. For example, to get _all_ rows of DataFrame ```df``` where, in in column ```x``` the value is greater than 0.5, you can use ```df[df["x"] > 0.5]```.
#
# Note that in this example, you are only subsetting based on rows. You are including _all_ columns.
#
# The benefit of this method is that it reads and writes more easily.

# %% [markdown]
# Q2.4.2. Write code in the new way shown, that will provide the same output as the answer for Q10, however, this time showing all columns.

# %%
# A2.4.2.
gl_data[gl_data["Debit/Credit"] == "Debit"]
# Out:
#              Date   Period                                        Description  \
# 0      2024-01-01  2024-01                   Accrual for Rent - Landlord Inc.
# 2      2024-01-01  2024-01             Accrual for Water bill - Waternet B.V.
# 4      2024-01-01  2024-01  Accrual for Statutory Audit - Tech Audit Firm ...
# 6      2024-01-01  2024-01                  Payroll expenses for 10 employees
# 7      2024-01-01  2024-01                  Payroll expenses for 10 employees
# ...           ...      ...                                                ...
# 967962 2025-02-15  2025-02                                Payment to Supplier
# 967964 2025-02-16  2025-02                                Payment to Supplier
# 967966 2025-02-18  2025-02                                Payment to Supplier
# 967968 2025-02-21  2025-02                                Payment to Supplier
# 967970 2025-02-23  2025-02                                Payment to Supplier
#
#        JournalCode      JournalDesc JournalType    Booknr  AccountCode  \
# 0               GJ  General Journal     General  GJ069234         4100
# 2               GJ  General Journal     General  GJ069246         4201
# 4               GJ  General Journal     General  GJ069258         4200
# 6               PJ  Payroll Journal     Payroll  PJ000002         4010
# 7               PJ  Payroll Journal     Payroll  PJ000002         4015
# ...            ...              ...         ...       ...          ...
# 967962          CJ     Cash Journal        Cash  CJ195702         1300
# 967964          CJ     Cash Journal        Cash  CJ195819         1300
# 967966          CJ     Cash Journal        Cash  CJ196283         1300
# 967968          CJ     Cash Journal        Cash  CJ196199         1300
# 967970          CJ     Cash Journal        Cash  CJ195827         1300
#
#                             AccountDesc AccountType Debit/Credit    Amount  \
# 0                          Rent Expense     Expense        Debit   1200.00
# 2                             Utilities     Expense        Debit     80.00
# 4             Accounting and Audit Fees     Expense        Debit  10000.00
# 6                           Gross wages     Expense        Debit  30000.00
# 7       Change Provision vacation bonus     Expense        Debit   2400.00
# ...                                 ...         ...          ...       ...
# 967962                        Creditors   Liability        Debit   1172.08
# 967964                        Creditors   Liability        Debit   8315.01
# 967966                        Creditors   Liability        Debit   2493.65
# 967968                        Creditors   Liability        Debit    165.19
# 967970                        Creditors   Liability        Debit    143.46
#
#         Product ID             User Relation_id        Relation_name  \
# 0              NaN              NaN         NaN                  NaN
# 2              NaN              NaN         NaN                  NaN
# 4              NaN              NaN         NaN                  NaN
# 6              NaN              NaN         NaN                  NaN
# 7              NaN              NaN         NaN                  NaN
# ...            ...              ...         ...                  ...
# 967962         NaN     hafsa_bouali  SUPL000057           NMC Health
# 967964         NaN          dbadmin  SUPL000097  Toshiba Corporation
# 967966         NaN     hafsa_bouali  SUPL000017         Pon Holdings
# 967968         NaN          dbadmin  SUPL000008                Exact
# 967970         NaN  leon_vandermeer  SUPL000094       Schiphol Group
#
#                                      Account
# 0                          4100 Rent Expense
# 2                             4201 Utilities
# 4             4200 Accounting and Audit Fees
# 6                           4010 Gross wages
# 7       4015 Change Provision vacation bonus
# ...                                      ...
# 967962                        1300 Creditors
# 967964                        1300 Creditors
# 967966                        1300 Creditors
# 967968                        1300 Creditors
# 967970                        1300 Creditors
#
# [388238 rows x 17 columns]

# %% [markdown]
# You can use this way of conditional indexing to create subsets based on multiple conditions. For example, ```df[(df["x"] > 0.5) | (df["y"] > 0.5)]```, will provide a subset of the ```df``` DataFrame with only the rows where in columns ```x``` **or** ```y``` the values are greater than 0.5. If you want to access data with multiple _and_ conditions, you can use the ```&``` operator.
#
#
# df[<span style="color:blue">(df["x"] > 0.5)</span> <span style="color:orange">|</span> <span style="color:blue">(df["y"] > 0.5)</span>]
# * In <span style="color:blue">Blue, you can see the conditions</span> that are used to subset the data. Notice they are in brackets? This is important to separate the conditions.
# * The <span style="color:orange;">|</span> is the _or_ operator. This means that if either of the conditions is met, the row will be included in the subset.
#
#
# Short recap:
# - ```|``` is the _or_ operator
# - ```&``` is the _and_ operator
# - Brackets `(` and `)` are important to separate the conditions. They work the same way as in mathematics.

# %% [markdown]
# Q2.4.3a. Create a subset of ```spotify_data``` that contains only data that meets the following conditions:
# * ```AccountDesc``` = `Revenue digital music`
# * ```Amount``` > 30

# %%
# A2.4.3a
gl_data[(gl_data['AccountDesc'] == 'Revenue digital music') & (gl_data['Amount'] > 30)]
# Out:
#              Date   Period                 Description JournalCode  \
# 4331   2024-01-03  2024-01  Digijazz.nl Order - Mp3601          SJ
# 5717   2024-01-03  2024-01  Digijazz.nl Order - Mp3161          SJ
# 10110  2024-01-05  2024-01  Digijazz.nl Order - Mp3354          SJ
# 12675  2024-01-06  2024-01  Digijazz.nl Order - Mp3871          SJ
# 13104  2024-01-06  2024-01  Digijazz.nl Order - Mp3153          SJ
# ...           ...      ...                         ...         ...
# 941301 2024-12-22  2024-12  Digijazz.nl Order - Mp3562          SJ
# 947212 2024-12-24  2024-12  Digijazz.nl Order - Mp3788          SJ
# 953979 2024-12-27  2024-12  Digijazz.nl Order - Mp3483          SJ
# 957193 2024-12-28  2024-12  Digijazz.nl Order - Mp3245          SJ
# 964254 2024-12-31  2024-12  Digijazz.nl Order - Mp3177          SJ
#
#           JournalDesc JournalType    Booknr  AccountCode  \
# 4331    Sales Journal       Sales  SJ019494         8000
# 5717    Sales Journal       Sales  SJ185523         8000
# 10110   Sales Journal       Sales  SJ083895         8000
# 12675   Sales Journal       Sales  SJ075038         8000
# 13104   Sales Journal       Sales  SJ126961         8000
# ...               ...         ...       ...          ...
# 941301  Sales Journal       Sales  SJ065674         8000
# 947212  Sales Journal       Sales  SJ144034         8000
# 953979  Sales Journal       Sales  SJ016316         8000
# 957193  Sales Journal       Sales  SJ087323         8000
# 964254  Sales Journal       Sales  SJ014456         8000
#
#                   AccountDesc AccountType Debit/Credit  Amount  Product ID  \
# 4331    Revenue digital music     Revenue       Credit   40.50      1000.0
# 5717    Revenue digital music     Revenue       Credit   74.90      1000.0
# 10110   Revenue digital music     Revenue       Credit   71.90      1000.0
# 12675   Revenue digital music     Revenue       Credit   58.90      1000.0
# 13104   Revenue digital music     Revenue       Credit   33.00      1000.0
# ...                       ...         ...          ...     ...         ...
# 941301  Revenue digital music     Revenue       Credit   35.90      1000.0
# 947212  Revenue digital music     Revenue       Credit   77.00      1000.0
# 953979  Revenue digital music     Revenue       Credit   47.99      1000.0
# 957193  Revenue digital music     Revenue       Credit   48.95      1000.0
# 964254  Revenue digital music     Revenue       Credit   71.00      1000.0
#
#                    User Relation_id       Relation_name  \
# 4331    MagentoImporter  CUST000138   Hans van der Meer
# 5717    MagentoImporter  CUST000262  Tom van den Heuvel
# 10110   MagentoImporter  CUST000152     Thomas van Dijk
# 12675   MagentoImporter  CUST000028      Laura de Groot
# 13104   MagentoImporter  CUST000205        Basma Amrani
# ...                 ...         ...                 ...
# 941301  MagentoImporter  CUST000097      Jasmijn de Wit
# 947212  MagentoImporter  CUST000080  Fleur van der Laan
# 953979  MagentoImporter  CUST000049  Dirk van der Velde
# 957193  MagentoImporter  CUST000251      Rick Schuurman
# 964254  MagentoImporter  CUST000159  Hicham Ait Mansour
#
#                            Account
# 4331    8000 Revenue digital music
# 5717    8000 Revenue digital music
# 10110   8000 Revenue digital music
# 12675   8000 Revenue digital music
# 13104   8000 Revenue digital music
# ...                            ...
# 941301  8000 Revenue digital music
# 947212  8000 Revenue digital music
# 953979  8000 Revenue digital music
# 957193  8000 Revenue digital music
# 964254  8000 Revenue digital music
#
# [176 rows x 17 columns]

# %% [markdown]
# Q2.4.3b. Do you remember from our Understanding of the Entity the sales prices of Vinyl and Download products? Why do you we select lines with an amount higher than 30?

# %% [markdown]
# A2.4.3b.
# Because from prior years and management inquiry, we know that the sales prices of Download products are usually <30.
# We are conducting data analytics for risk analysis. Because we identified various transactions with an amount higher than 30, we want to investigate these transactions further. Potentially, we should raise an audit risk for the accuracy of revenues from digital music.

# %% [markdown]
# You can see how many rows meet specific conditions by using the ```len``` function. For example, you can type ```len(df.loc[df.loc[:,'x']>1,'x'])``` to show the number of rows in column ```x``` that have a valaue greater than 1.

# %% [markdown]
# Q2.4.4. As always, you can save data by assigning it to a variable name. Save the subset above as ```subset_price_analysis```.

# %%
# A2.4.4.
subset_price_analysis = gl_data[(gl_data['AccountDesc'] == 'Revenue digital music') & (gl_data['Amount'] > 30)]
subset_price_analysis
# Out:
#              Date   Period                 Description JournalCode  \
# 4331   2024-01-03  2024-01  Digijazz.nl Order - Mp3601          SJ
# 5717   2024-01-03  2024-01  Digijazz.nl Order - Mp3161          SJ
# 10110  2024-01-05  2024-01  Digijazz.nl Order - Mp3354          SJ
# 12675  2024-01-06  2024-01  Digijazz.nl Order - Mp3871          SJ
# 13104  2024-01-06  2024-01  Digijazz.nl Order - Mp3153          SJ
# ...           ...      ...                         ...         ...
# 941301 2024-12-22  2024-12  Digijazz.nl Order - Mp3562          SJ
# 947212 2024-12-24  2024-12  Digijazz.nl Order - Mp3788          SJ
# 953979 2024-12-27  2024-12  Digijazz.nl Order - Mp3483          SJ
# 957193 2024-12-28  2024-12  Digijazz.nl Order - Mp3245          SJ
# 964254 2024-12-31  2024-12  Digijazz.nl Order - Mp3177          SJ
#
#           JournalDesc JournalType    Booknr  AccountCode  \
# 4331    Sales Journal       Sales  SJ019494         8000
# 5717    Sales Journal       Sales  SJ185523         8000
# 10110   Sales Journal       Sales  SJ083895         8000
# 12675   Sales Journal       Sales  SJ075038         8000
# 13104   Sales Journal       Sales  SJ126961         8000
# ...               ...         ...       ...          ...
# 941301  Sales Journal       Sales  SJ065674         8000
# 947212  Sales Journal       Sales  SJ144034         8000
# 953979  Sales Journal       Sales  SJ016316         8000
# 957193  Sales Journal       Sales  SJ087323         8000
# 964254  Sales Journal       Sales  SJ014456         8000
#
#                   AccountDesc AccountType Debit/Credit  Amount  Product ID  \
# 4331    Revenue digital music     Revenue       Credit   40.50      1000.0
# 5717    Revenue digital music     Revenue       Credit   74.90      1000.0
# 10110   Revenue digital music     Revenue       Credit   71.90      1000.0
# 12675   Revenue digital music     Revenue       Credit   58.90      1000.0
# 13104   Revenue digital music     Revenue       Credit   33.00      1000.0
# ...                       ...         ...          ...     ...         ...
# 941301  Revenue digital music     Revenue       Credit   35.90      1000.0
# 947212  Revenue digital music     Revenue       Credit   77.00      1000.0
# 953979  Revenue digital music     Revenue       Credit   47.99      1000.0
# 957193  Revenue digital music     Revenue       Credit   48.95      1000.0
# 964254  Revenue digital music     Revenue       Credit   71.00      1000.0
#
#                    User Relation_id       Relation_name  \
# 4331    MagentoImporter  CUST000138   Hans van der Meer
# 5717    MagentoImporter  CUST000262  Tom van den Heuvel
# 10110   MagentoImporter  CUST000152     Thomas van Dijk
# 12675   MagentoImporter  CUST000028      Laura de Groot
# 13104   MagentoImporter  CUST000205        Basma Amrani
# ...                 ...         ...                 ...
# 941301  MagentoImporter  CUST000097      Jasmijn de Wit
# 947212  MagentoImporter  CUST000080  Fleur van der Laan
# 953979  MagentoImporter  CUST000049  Dirk van der Velde
# 957193  MagentoImporter  CUST000251      Rick Schuurman
# 964254  MagentoImporter  CUST000159  Hicham Ait Mansour
#
#                            Account
# 4331    8000 Revenue digital music
# 5717    8000 Revenue digital music
# 10110   8000 Revenue digital music
# 12675   8000 Revenue digital music
# 13104   8000 Revenue digital music
# ...                            ...
# 941301  8000 Revenue digital music
# 947212  8000 Revenue digital music
# 953979  8000 Revenue digital music
# 957193  8000 Revenue digital music
# 964254  8000 Revenue digital music
#
# [176 rows x 17 columns]

# %%
len(subset_price_analysis)
# Out:
# 176

# %% [markdown]
# Q2.4.5. To assess this number, it helps to understand the percentage of those unexpected values of the total Digital Orders dataset. Calculate the percentage of the subset of the total dataset using the `len` function.

# %%
# A2.4.5.
high_prices = len(subset_price_analysis)
all_digital_orders = len(gl_data[gl_data['AccountDesc'] == 'Revenue digital music'])
percentage = high_prices / all_digital_orders * 100
print("In total there are", all_digital_orders, "digital music orders, of which", high_prices, "are above 30 EUR. This means that", round(percentage,1), "% of the digital music orders are above 30 EUR.")
# Out:
# In total there are 96517 digital music orders, of which 176 are above 30 EUR. This means that 0.2 % of the digital music orders are above 30 EUR.

# %% [markdown]
# Q2.4.6. Discuss with your neighbors what the percentage means and how you can interpret it. What should you do with this new information?

# %% [markdown]
# A2.4.6.
# Open for discussion.

# %% [markdown]
# ### 3. Compound Data structures: Exercises
#
# Make sure you review the cheatsheet on compound data structures before you start with the exercises.

# %% [markdown]
# ### 3.1. Introduction to compound data structures

# %% [markdown]
# Q3.1.1. Can you name the compound data structures shown below?

# %% [markdown]
# A3.1.1. ```fruits``` is a list, ```vegetables``` is a tuple, and ```restaurant_booking``` is a dictionary.

# %%
currencies = ["EUR", "USD", "GBP", "JPY"]
stocks = ("Apple", "Microsoft", "Tesla")
gl_account = {"code": 1200, "desc": "debtors"}

print(currencies)
print(stocks)
print(gl_account)
# Out:
# ['EUR', 'USD', 'GBP', 'JPY']
# ('Apple', 'Microsoft', 'Tesla')
# {'code': 1200, 'desc': 'debtors'}

# %% [markdown]
# Q3.1.2. How could you identify the data types of these compound data structures without looking at them (hint: think back to Lecture 1)?

# %% [markdown]
# A3.1.2. Using ```type()``` you can identify the type of each.

# %%
# A3.2.1.
type_currencies = type(currencies)
type_stocks = type(stocks)
type_gl_account = type(gl_account)
print(type_currencies, type_stocks, type_gl_account)
# Out:
# <class 'list'> <class 'tuple'> <class 'dict'>

# %% [markdown]
# ### 3.2. Lists in practice

# %% [markdown]
# Q3.2.1. Make a list of the first four column names in the ```gl_data``` dataset.
#
# Hint: You have two options:
# 1. You can make a list using square brackets (```[]```)
# 2. However, it is quicker to access the column names using the ```columns``` attribute and then selecting the first four column names by indexing.

# %%
# Option 1: Making a list manually:
column_names_manual = ['Date', 'Period', 'Description', 'JournalCode']
print(column_names_manual)


# Option 2: Making a list using the columns() function and indexing:
column_names_index = list(gl_data.columns)[0:4]
print(column_names_index)
# Out:
# ['Date', 'Period', 'Description', 'JournalCode']
# ['Date', 'Period', 'Description', 'JournalCode']

# %% [markdown]
# Q3.2.2. Make a new list called ```subset_column_names``` that consists of only the ```Period``` and ```JournalCode``` columns of the ```column_names_index``` list you have just created. Hint! Do this by indexing! Refer to the cheatsheet if you need help.

# %% [markdown]
# A3.2.2. While you could create the new list using square brackets (```[]```), it is easier to use indexing as follows:

# %% [markdown]
# <mark>Ik vind dit eerlijk gezegd een heel ongebruikelijke methode van indexing; hoogst verwarrend,
# slecht te reviewen (in productie/professionele setting) en zou het er liever
# uit laten. Maar dan moeten we het niet op tentamen ineens uitvragen..
# In de praktijk zou ik altijd indexeren obv column names, want die zijn (redelijk) consistent, de volgorde van kolommen exports wijzigt nogal eens.</mark>

# %%
subset_column_names = column_names_index[1:4:2]
print(subset_column_names)
# Out:
# ['Period', 'JournalCode']

# %% [markdown]
# Q3.3.3. Add the ```AccountCode``` to the ```subset_column_names``` list.

# %%
# A3.3.3. You can add the ```AccountCode``` variable through ```append()```.
subset_column_names.append("AccountCode")
print(subset_column_names)
# Out:
# ['Period', 'JournalCode', 'AccountCode']

# %% [markdown]
# <mark>Ik heb hier een aantal vragen weggehaald die herhaling zijn (append, insert, etc.) en IMHO niet zo veel educatieve waarde meer hebben. Wmb geen bezwaar om ze evt alsnog toe tevoegen.</mark>

# %% [markdown]
# ### 3.3. Tuples and sets

# %%
# We're going to analyze revenue data a few times.

# For convenience, let's create a subset of the data and store this dataframe in a new variable.
# This way, we can quickly access the data we need for the analysis, without having to filter the data every time.

df_revenue = gl_data[gl_data['AccountDesc'] == 'Revenue digital music'].reset_index(drop=True)
df_revenue.head(3)
# Out:
#         Date   Period                 Description JournalCode    JournalDesc  \
# 0 2024-01-01  2024-01  Digijazz.nl Order - Mp3496          SJ  Sales Journal
# 1 2024-01-01  2024-01  Digijazz.nl Order - Mp3651          SJ  Sales Journal
# 2 2024-01-01  2024-01  Digijazz.nl Order - Mp3690          SJ  Sales Journal
#
#   JournalType    Booknr  AccountCode            AccountDesc AccountType  \
# 0       Sales  SJ001027         8000  Revenue digital music     Revenue
# 1       Sales  SJ002740         8000  Revenue digital music     Revenue
# 2       Sales  SJ003844         8000  Revenue digital music     Revenue
#
#   Debit/Credit  Amount  Product ID             User Relation_id  \
# 0       Credit   6.900      1000.0  MagentoImporter  CUST000066
# 1       Credit  14.885      1000.0  bram_vanleeuwen  CUST000101
# 2       Credit  17.500      1000.0  MagentoImporter  CUST000130
#
#        Relation_name                     Account
# 0  Tess van den Berg  8000 Revenue digital music
# 1     Thijs de Groot  8000 Revenue digital music
# 2       Rick Janssen  8000 Revenue digital music

# %% [markdown]
# In the dataset, you can find the column ```User```. This column contains the username that posted the transaction. It might be interesting, for our risk analysis, to know how many unique users are in the dataset.

# %%
# Create a list of users, and report the first 5
users = list(df_revenue.User)
users[0:5]
# Out:
# ['MagentoImporter',
#  'bram_vanleeuwen',
#  'MagentoImporter',
#  'MagentoImporter',
#  'MagentoImporter']

# %% [markdown]
# Q3.3.1. What happens if we convert the ```users``` list into a tuple called ```tuple_users```?

# %% [markdown]
# A3.3.1. Using the ```tuple()``` function we can convert the original ```users``` list to a tuple. As you can see, the resulting tuple includes a long list of usernames. It's hard to see how many unique users there are in the dataset.

# %%
#A3.3.1
tuple_users = tuple(users)
print(tuple_users)
tuple_users[0:5]
# Out:
# ('MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'bram_vanleeuwen', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'bram_vanleeuwen', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoImporter', 'MagentoI ...
# ('MagentoImporter',
#  'bram_vanleeuwen',
#  'MagentoImporter',
#  'MagentoImporter',
#  'MagentoImporter')

# %% [markdown]
# Q3.3.2. What happens if we convert the ```users``` list into a set called ```set_users```? Why is this different from creating a tuple?

# %% [markdown]
# A3.3.2) In the set, ```set_users```, only one instance of the each item remains. This is because a set cannot contain duplicates.

# %%
#A3.3.2
set_users = set(users)
print(set_users)
# Out:
# {'MagentoImporter', 'bram_vanleeuwen'}

# %% [markdown]
# As you can see, the `set` is a very useful data structure to quickly identify unique values in a dataset. It's important that you understand the difference between a `list`/`tuple` and a `set`, and when to use each of them.

# %% [markdown]
# ### 3.4. Dictionaries in practice

# %% [markdown]
# Before you start, this could be a good moment to reflect on your understanding of Dictionaries. If you are not sure, please review the cheatsheet.

# %% [markdown]
# Q3.4.1. Create a dictionary called ```revenue_per_order``` with the first two orders from the ```revenue_df``` dataset, with `Booknr` and `Amount` as the keys and values, respectively. In `Booknr` the Order ID's are stored.
#
# Hint: you may want to use ```print(df_revenue.loc[0:1,("Booknr","Amount")])``` first to see which artists and albums are in the first three rows.

# %%
# preparation for A3.4.1
print(df_revenue.loc[0:1,("Booknr","Amount")])
# Out:
#      Booknr  Amount
# 0  SJ001027   6.900
# 1  SJ002740  14.885

# %% [markdown]
# A3.4.1. You can create a dictionary curly brackets, ```{}```.

# %%
revenue_per_order = {
                'SJ000362': 1.5,
                'SJ000890': 0.5,
            }

print(revenue_per_order)
# Out:
# {'SJ000362': 1.5, 'SJ000890': 0.5}

# %% [markdown]
# Q3.4.2. What if we wanted to make a dictionary of _all_ of items in these two columns? Doing this manually would be a lot of work. What is the alternative? What is the benefit of this method?

# %% [markdown]
# A3.4.2. We can use the ```zip()``` function to combine the ```Booknr``` and ```Amount``` columns into a dictionary. The benefit of this is that it avoids mistakes, such as mismatched key-value pairs.

# %%
revenue_per_order = dict(zip(df_revenue.Booknr, df_revenue.Amount))
revenue_per_order
# Out:
# {'SJ001027': 6.9,
#  'SJ002740': 14.885,
#  'SJ003844': 17.5,
#  'SJ004191': 10.0,
#  'SJ004908': 25.95,
#  'SJ004923': 17.875,
#  'SJ005127': 22.5,
#  'SJ006059': 2.9,
#  'SJ007868': 3.9,
#  'SJ008528': 27.5,
#  'SJ009457': 21.5,
#  'SJ009979': 12.0,
#  'SJ010305': 5.99,
#  'SJ012380': 10.985,
#  'SJ015493': 18.85,
#  'SJ015772': 21.5,
#  'SJ016162': 21.5,
#  'SJ016298': 18.525,
#  'SJ016736': 25.9,
#  'SJ017933': 2.5,
#  'SJ017942': 13.5,
#  'SJ020518': 24.0,
#  'SJ020997': 5.0,
#  'SJ022154': 28.5,
#  'SJ022389': 2.925,
#  'SJ023079': 17.485,
#  'SJ023209': 26.5,
#  'SJ023673': 9.9,
#  'SJ024065': 7.475000000000001,
#  'SJ026513': 25.95,
#  'SJ026564': 13.5,
#  'SJ026751': 29.0,
#  'SJ027840': 7.0,
#  'SJ028958': 15.6,
#  'SJ029369': 18.5,
#  'SJ030036': 19.435,
#  'SJ030313': 21.5,
#  'SJ030879': 23.5,
#  'SJ035497': 14.5,
#  'SJ036923': 0.5850000000000001,
#  'SJ037333': 17.875,
#  'SJ037340': 8.5,
#  'SJ037491': 5.5,
#  'SJ037535': 16.5,
#  'SJ039593': 4.5,
#  'SJ040800': 5.95,
#  'SJ045720': 27.9,
#  'SJ046726': 27.95,
#  'SJ048908': 18.5,
#  'SJ049999': 8.5,
#  'SJ050573': 15.275,
#  'SJ051246': 29.5,
#  'SJ051266': 16.25,
#  'SJ052524': 22.5,
#  'SJ053163': 23.0,
#  'SJ053251': 25.9,
#  'SJ053468': 23.5,
#  'SJ053541': 23.9,
#  'SJ053905': 18.0,
#  'SJ054310': 2.0,
#  'SJ055959': 6.0,
#  'SJ056153': 14.9,
#  'SJ056314': 4.875,
#  'SJ056963': 2.275,
#  'SJ057622': 6.0,
#  'SJ057970': 15.0,
#  'SJ059764': 8.0,
#  'SJ060482': 1.3,
#  'SJ061505': 13.9,
#  'SJ061562': 18.5,
#  'SJ061758': 25.95,
#  'SJ061903': 1.5,
#  'SJ062373': 7.5,
#  'SJ064287': 2.275,
#  'SJ064301': 29.9,
#  'SJ065252': 7.5,
#  'SJ066047': 25.5,
#  'SJ066069': 2.0,
#  'SJ066440': 27.0,
#  'SJ066603': 7.9,
#  'SJ067227': 26.9,
#  'SJ067718': 22.0,
#  'SJ067899': 10.3935,
#  'SJ068103': 14.0,
#  'SJ068459': 12.35,
#  'SJ069917': 19.9,
#  'SJ070229': 29.9,
#  'SJ070273': 22.0,
#  'SJ070727': 18.0,
#  'SJ071238': 6.9,
#  'SJ074690': 12.5,
#  'SJ076231': 22.0,
#  'SJ076694': 3.95,
#  'SJ076925': 19.0,
#  'SJ078261': 1.625,
#  'SJ079173': 1.95,
#  'SJ079294': 19.9,
#  'SJ081515': 16.5,
#  'SJ083514': 16.5,
#  'SJ084744': 7.0,
#  'SJ085176': 12.5,
#  'SJ085216': 9.5,
#  'SJ085316': 18.525,
#  'SJ085649': 21.9,
#  'SJ085982': 29.5,
#  'SJ086247': 12.5,
#  'SJ086957': 29.95,
#  'SJ087395': 15.275,
#  'SJ087495': 11.5,
#  'SJ087631': 17.9,
#  'SJ087869': 29.99,
#  'SJ088074': 4.5175,
#  'SJ088263': 19.0,
#  'SJ088512': 5.5,
#  'SJ091010': 10.5,
#  'SJ091315': 28.5,
#  'SJ091815': 9.5,
#  'SJ092802': 10.9,
#  'SJ094694': 2.5,
#  'SJ095780': 5.0,
#  'SJ096353': 4.0,
#  'SJ097453': 8.125,
#  'SJ097700': 3.25,
#  'SJ098612': 20.5,
#  'SJ098845': 13.9,
#  'SJ099051': 11.7,
#  'SJ099295': 6.175,
#  'SJ099438': 14.5,
#  'SJ099961': 7.5,
#  'SJ100513': 5.5,
#  'SJ100851': 20.5,
#  'SJ101512': 24.95,
#  'SJ101828': 1.0,
#  'SJ102135': 11.5,
#  'SJ103489': 5.525,
#  'SJ103717': 5.525,
#  'SJ104341': 1.9,
#  'SJ107026': 27.95,
#  'SJ107052': 3.9,
#  'SJ107760': 6.5,
#  'SJ109897': 18.5,
#  'SJ110428': 5.1675,
#  'SJ110440': 29.5,
#  'SJ110594': 5.5,
#  'SJ111893': 2.0,
#  'SJ112684': 20.0,
#  'SJ112839': 7.95,
#  'SJ113151': 11.0,
#  'SJ113719': 7.475000000000001,
#  'SJ113975': 19.9,
#  'SJ115502': 3.5,
#  'SJ117914': 27.5,
#  'SJ119077': 14.95,
#  'SJ120503': 4.485,
#  'SJ121810': 9.0,
#  'SJ123167': 22.0,
#  'SJ123399': 24.0,
#  'SJ123436': 21.5,
#  'SJ123711': 18.0,
#  'SJ123821': 18.9,
#  'SJ124267': 14.625,
#  'SJ125076': 1.5,
#  'SJ125210': 2.9,
#  'SJ125415': 21.5,
#  'SJ125768': 15.6,
#  'SJ126761': 1.5,
#  'SJ126994': 12.5,
#  'SJ128030': 10.95,
#  'SJ128189': 27.9,
#  'SJ128706': 1.9,
#  'SJ129236': 15.0,
#  'SJ129504': 1.0,
#  'SJ129770': 15.5,
#  'SJ129855': 29.0,
#  'SJ130030': 23.5,
#  'SJ130290': 1.2675,
#  'SJ131372': 2.5935,
#  'SJ131811': 4.5,
#  'SJ131895': 24.5,
#  'SJ131964': 27.5,
#  'SJ134219': 6.5,
#  'SJ135644': 1.0,
#  'SJ136498': 16.9,
#  'SJ137507': 5.5,
#  'SJ139423': 1.625,
#  'SJ139505': 6.9,
#  'SJ139662': 13.65,
#  'SJ140057': 16.25,
#  'SJ140509': 10.9,
#  'SJ141277': 9.9,
#  'SJ142329': 20.5,
#  'SJ142333': 10.9,
#  'SJ142472': 4.55,
#  'SJ142685': 5.5,
#  'SJ142923': 1.5,
#  'SJ143172': 0.9750000000000001,
#  'SJ143326': 8.9,
#  'SJ143546': 27.9,
#  'SJ143619': 3.5,
#  'SJ144304': 18.85,
#  'SJ145034': 16.0,
#  'SJ146011': 12.5,
#  'SJ146119': 26.5,
#  'SJ147156': 9.5,
#  'SJ149233': 18.785,
#  'SJ152285': 16.9,
#  'SJ152435': 1.5,
#  'SJ153343': 14.5,
#  'SJ153532': 29.5,
#  'SJ153795': 11.5,
#  'SJ154666': 9.0,
#  'SJ155455': 14.95,
#  'SJ155523': 27.9,
#  'SJ155847': 8.95,
#  'SJ156427': 12.025,
#  'SJ156930': 5.5,
#  'SJ156970': 0.9750000000000001,
#  'SJ157055': 18.0,
#  'SJ157551': 8.0,
#  'SJ157826': 16.5,
#  'SJ158334': 24.5,
#  'SJ159991': 19.0,
#  'SJ162161': 14.5,
#  'SJ163134': 11.05,
#  'SJ163431': 4.5,
#  'SJ164228': 6.0,
#  'SJ165627': 9.685,
#  'SJ166097': 10.725,
#  'SJ166117': 15.535,
#  'SJ166192': 10.5,
#  'SJ166571': 14.0,
#  'SJ168854': 5.95,
#  'SJ168920': 25.0,
#  'SJ169312': 23.5,
#  'SJ169542': 25.0,
#  'SJ170676': 21.5,
#  'SJ170895': 14.0,
#  'SJ171347': 7.5,
#  'SJ171959': 6.9,
#  'SJ175203': 19.5,
#  'SJ176898': 8.9,
#  'SJ177318': 8.9,
#  'SJ178087': 7.0,
#  'SJ178686': 28.9,
#  'SJ180648': 1.5,
#  'SJ180806': 10.0,
#  'SJ180948': 13.0,
#  'SJ181620': 11.5,
#  'SJ181757': 11.9,
#  'SJ182627': 21.5,
#  'SJ182904': 10.725,
#  'SJ182930': 18.5,
#  'SJ182999': 7.085000000000001,
#  'SJ184082': 28.5,
#  'SJ184187': 10.3935,
#  'SJ184931': 5.5,
#  'SJ185257': 12.5,
#  'SJ185324': 16.5,
#  'SJ185379': 10.0,
#  'SJ185617': 14.5,
#  'SJ187032': 14.5,
#  'SJ187464': 17.5,
#  'SJ187654': 13.325,
#  'SJ188711': 11.5,
#  'SJ189810': 12.5,
#  'SJ190278': 10.725,
#  'SJ190406': 19.5,
#  'SJ190510': 17.5,
#  'SJ191475': 14.9,
#  'SJ191830': 17.9,
#  'SJ000464': 7.1435,
#  'SJ000559': 17.0,
#  'SJ000753': 28.0,
#  'SJ000964': 27.5,
#  'SJ001572': 29.9,
#  'SJ002067': 5.850000000000001,
#  'SJ006421': 6.175,
#  'SJ006581': 13.0,
#  'SJ008125': 13.9,
#  'SJ008555': 2.9,
#  'SJ008883': 12.5,
#  'SJ009069': 3.9,
#  'SJ010828': 2.99,
#  'SJ011373': 9.5,
#  'SJ011557': 0.9,
#  'SJ012303': 10.5,
#  'SJ012597': 5.5,
#  'SJ012629': 12.5,
#  'SJ012780': 24.9,
#  'SJ014461': 3.9,
#  'SJ015587': 14.625,
#  'SJ017213': 10.9,
#  'SJ017491': 17.5,
#  'SJ018307': 2.925,
#  'SJ018779': 15.9,
#  'SJ019443': 16.9,
#  'SJ020376': 3.5,
#  'SJ021211': 7.475000000000001,
#  'SJ021506': 5.0,
#  'SJ022479': 25.0,
#  'SJ022540': 12.5,
#  'SJ023961': 26.0,
#  'SJ023984': 3.9,
#  'SJ024949': 26.5,
#  'SJ025250': 6.825,
#  'SJ026128': 3.9,
#  'SJ026177': 24.0,
#  'SJ027558': 6.5,
#  'SJ029881': 13.5,
#  'SJ030555': 12.5,
#  'SJ031272': 21.5,
#  'SJ032189': 10.985,
#  'SJ032370': 16.9,
#  'SJ032664': 1.95,
#  'SJ032913': 8.5,
#  'SJ033518': 5.5,
#  'SJ033573': 8.775,
#  'SJ035024': 13.65,
#  'SJ035992': 6.9,
#  'SJ036675': 19.0,
#  'SJ037310': 16.5,
#  'SJ038027': 9.1,
#  'SJ038045': 8.5,
#  'SJ039212': 18.0,
#  'SJ039538': 21.9,
#  'SJ040382': 4.0,
#  'SJ043257': 6.5,
#  'SJ043548': 7.0,
#  'SJ043746': 24.5,
#  'SJ044043': 16.185,
#  'SJ046783': 9.685,
#  'SJ046828': 13.5,
#  'SJ047446': 16.9,
#  'SJ049119': 21.9,
#  'SJ050529': 25.95,
#  'SJ050767': 10.9,
#  'SJ051270': 7.0,
#  'SJ054523': 27.5,
#  'SJ055330': 13.0,
#  'SJ055653': 25.0,
#  'SJ055940': 2.275,
#  'SJ056531': 14.5,
#  'SJ057207': 14.9,
#  'SJ057627': 15.925,
#  'SJ057978': 7.5,
#  'SJ058189': 18.0,
#  'SJ060174': 6.5,
#  'SJ060508': 3.9,
#  'SJ060644': 3.575,
#  'SJ062343': 27.9,
#  'SJ063607': 10.5,
#  'SJ064310': 12.0,
#  'SJ065299': 13.95,
#  'SJ065597': 20.0,
#  'SJ066016': 5.0,
#  'SJ066029': 5.5,
#  'SJ066628': 1.5,
#  'SJ067448': 16.8675,
#  'SJ067922': 1.5,
#  'SJ068040': 9.5,
#  'SJ068137': 9.685,
#  'SJ068706': 26.95,
#  'SJ069106': 16.0,
#  'SJ069455': 18.135,
#  'SJ070359': 9.9,
#  'SJ070705': 10.5,
#  'SJ070991': 21.9,
#  'SJ071178': 2.5,
#  'SJ072431': 21.9,
#  'SJ072907': 7.475000000000001,
#  'SJ073212': 22.5,
#  'SJ073685': 27.5,
#  'SJ075512': 15.9,
#  'SJ075528': 10.4,
#  'SJ075550': 9.035,
#  'SJ075738': 3.835,
#  'SJ077788': 1.625,
#  'SJ077912': 21.0,
#  'SJ080482': 22.9,
#  'SJ080498': 0.95,
#  'SJ081495': 18.99,
#  'SJ081521': 20.5,
#  'SJ081622': 18.9,
#  'SJ082389': 1.5,
#  'SJ084068': 7.085000000000001,
#  'SJ085615': 8.5,
#  'SJ086629': 7.0,
#  'SJ088760': 2.9,
#  'SJ090105': 8.5,
#  'SJ090818': 18.525,
#  'SJ091203': 24.0,
#  'SJ091252': 3.575,
#  'SJ092494': 17.5,
#  'SJ094100': 29.0,
#  'SJ094559': 15.5,
#  'SJ095763': 22.95,
#  'SJ096301': 14.95,
#  'SJ097051': 14.5,
#  'SJ097186': 21.9,
#  'SJ097889': 7.5,
#  'SJ098204': 7.475000000000001,
#  'SJ098389': 27.0,
#  'SJ099252': 19.5,
#  'SJ099670': 26.95,
#  'SJ100576': 2.0,
#  'SJ101156': 23.5,
#  'SJ101373': 20.5,
#  'SJ104314': 15.0,
#  'SJ104499': 26.5,
#  'SJ107466': 20.5,
#  'SJ108434': 9.5,
#  'SJ108793': 1.5,
#  'SJ110018': 20.5,
#  'SJ110522': 16.9,
#  'SJ112328': 25.0,
#  'SJ112464': 1.5,
#  'SJ112502': 2.275,
#  'SJ112611': 20.5,
#  'SJ113100': 22.9,
#  'SJ117640': 24.9,
#  'SJ117863': 9.035,
#  'SJ118058': 6.9,
#  'SJ118258': 1.0,
#  'SJ118472': 14.5,
#  'SJ120093': 22.5,
#  'SJ121276': 4.9,
#  'SJ122567': 27.95,
#  'SJ123141': 27.0,
#  'SJ123226': 19.5,
#  'SJ123869': 10.0,
#  'SJ125502': 18.0,
#  'SJ125984': 9.5,
#  'SJ126012': 13.9,
#  'SJ126293': 7.800000000000001,
#  'SJ126739': 11.5,
#  'SJ127287': 29.5,
#  'SJ129092': 17.225,
#  'SJ130713': 6.435,
#  'SJ131340': 8.775,
#  'SJ131413': 10.5,
#  'SJ131942': 9.1,
#  'SJ132290': 2.99,
#  'SJ133194': 26.9,
#  'SJ133960': 10.5,
#  'SJ133995': 9.9,
#  'SJ134178': 17.225,
#  'SJ134377': 12.0,
#  'SJ134669': 28.5,
#  'SJ135505': 10.99,
#  'SJ135968': 27.5,
#  'SJ136719': 12.5,
#  'SJ137330': 5.0,
#  'SJ137839': 3.8935,
#  'SJ139003': 3.9,
#  'SJ139131': 22.9,
#  'SJ139146': 15.5,
#  'SJ140466': 2.5935,
#  'SJ141630': 8.5,
#  'SJ142839': 27.5,
#  'SJ143276': 26.5,
#  'SJ143430': 17.5,
#  'SJ143490': 20.5,
#  'SJ143852': 14.5,
#  'SJ144033': 25.5,
#  'SJ144768': 10.5,
#  'SJ144885': 14.9175,
#  'SJ145815': 10.5,
#  'SJ148121': 15.5,
#  'SJ148392': 12.5,
#  'SJ148819': 17.225,
#  'SJ148840': 6.5,
#  'SJ149521': 5.5,
#  'SJ150297': 17.9,
#  'SJ151890': 14.9,
#  'SJ151998': 9.0,
#  'SJ152146': 25.95,
#  'SJ152248': 14.5,
#  'SJ152393': 28.0,
#  'SJ152522': 0.9,
#  'SJ153855': 12.5,
#  'SJ154728': 7.5,
#  'SJ154757': 17.99,
#  'SJ154920': 6.825,
#  'SJ155213': 21.5,
#  'SJ155261': 2.0,
#  'SJ155840': 9.5,
#  'SJ155849': 16.25,
#  'SJ156457': 15.925,
#  'SJ158417': 19.0,
#  'SJ158812': 24.0,
#  'SJ159412': 26.0,
#  'SJ159563': 19.5,
#  'SJ159638': 8.5,
#  'SJ160537': 26.5,
#  'SJ161557': 20.0,
#  'SJ161699': 13.9,
#  'SJ163610': 25.0,
#  'SJ164145': 23.5,
#  'SJ164407': 9.1,
#  'SJ164745': 19.5,
#  'SJ165927': 29.99,
#  'SJ167352': 19.9,
#  'SJ168271': 22.9,
#  'SJ170796': 25.5,
#  'SJ171327': 1.99,
#  'SJ171654': 10.5,
#  'SJ172323': 8.0,
#  'SJ172379': 16.5,
#  'SJ173510': 7.5,
#  'SJ173911': 19.9,
#  'SJ174152': 25.5,
#  'SJ174387': 13.5,
#  'SJ174637': 17.485,
#  'SJ174834': 16.95,
#  'SJ175634': 5.5,
#  'SJ175870': 20.95,
#  'SJ176436': 29.0,
#  'SJ176979': 4.5,
#  'SJ177832': 9.067499999999999,
#  'SJ180850': 11.5,
#  'SJ181267': 13.0,
#  'SJ181879': 19.9,
#  'SJ182712': 25.0,
#  'SJ182725': 6.5,
#  'SJ183073': 1.625,
#  'SJ184060': 3.835,
#  'SJ184250': 27.5,
#  'SJ184532': 12.9,
#  'SJ184562': 9.0,
#  'SJ184904': 1.95,
#  'SJ185633': 21.0,
#  'SJ185718': 14.5,
#  'SJ188893': 11.0,
#  'SJ189359': 12.99,
#  'SJ190429': 20.5,
#  'SJ191953': 17.5,
#  'SJ000231': 13.975,
#  'SJ001075': 21.0,
#  'SJ002021': 19.175,
#  'SJ002512': 25.9,
#  'SJ002630': 24.5,
#  'SJ003116': 3.0,
#  'SJ003118': 19.175,
#  'SJ004020': 24.95,
#  'SJ006918': 21.9,
#  'SJ007278': 7.475000000000001,
#  'SJ009678': 2.5,
#  'SJ010301': 18.525,
#  'SJ010783': 2.5,
#  'SJ011658': 9.9,
#  'SJ012243': 18.5,
#  'SJ012696': 23.5,
#  'SJ012770': 1.5,
#  'SJ013193': 6.825,
#  'SJ013509': 27.5,
#  'SJ013729': 10.725,
#  'SJ014831': 15.9,
#  'SJ014960': 6.5,
#  'SJ015937': 15.925,
#  'SJ016057': 16.9,
#  'SJ016172': 27.9,
#  'SJ016808': 17.99,
#  'SJ018357': 25.5,
#  'SJ018617': 25.9,
#  'SJ019027': 28.0,
#  'SJ019494': 40.5,
#  'SJ020464': 7.475000000000001,
#  'SJ021723': 26.0,
#  'SJ023379': 15.275,
#  'SJ024045': 4.5,
#  'SJ025352': 17.0,
#  'SJ025970': 7.0,
#  'SJ026289': 10.0,
#  'SJ027083': 10.0,
#  'SJ027161': 25.9,
#  'SJ027668': 17.5,
#  'SJ028189': 16.5,
#  'SJ028510': 9.0,
#  'SJ030051': 20.9,
#  'SJ030443': 23.5,
#  'SJ031218': 28.5,
#  'SJ031289': 11.05,
#  'SJ031350': 23.5,
#  'SJ031740': 2.5,
#  'SJ031874': 23.5,
#  'SJ032198': 6.9,
#  'SJ032439': 27.5,
#  'SJ032754': 24.0,
#  'SJ034271': 13.9,
#  'SJ035968': 18.0,
#  'SJ036305': 12.35,
#  'SJ037499': 7.5,
#  'SJ038065': 8.9,
#  'SJ038337': 13.325,
#  'SJ039118': 14.0,
#  'SJ041526': 16.575,
#  'SJ041662': 16.9,
#  'SJ041694': 12.025,
#  'SJ042259': 16.5,
#  'SJ043505': 12.025,
#  'SJ044260': 14.885,
#  'SJ044414': 12.285,
#  'SJ046093': 12.0,
#  'SJ046297': 9.75,
#  'SJ046349': 13.5,
#  'SJ046542': 22.5,
#  'SJ047033': 3.0,
#  'SJ047445': 29.9,
#  'SJ047917': 8.775,
#  'SJ048640': 14.2935,
#  'SJ048901': 24.5,
#  'SJ049113': 19.0,
#  'SJ049127': 4.5,
#  'SJ050410': 8.0,
#  'SJ050802': 5.9,
#  'SJ050821': 14.235,
#  'SJ051607': 4.5,
#  'SJ052898': 6.5,
#  'SJ053265': 14.0,
#  'SJ053422': 8.5,
#  'SJ054250': 17.9,
#  'SJ054662': 26.9,
#  'SJ055350': 20.5,
#  'SJ055552': 11.9,
#  'SJ055856': 13.9,
#  'SJ057092': 16.99,
#  'SJ057272': 10.0,
#  'SJ057643': 2.5,
#  'SJ058881': 29.0,
#  'SJ060188': 23.9,
#  'SJ060624': 21.9,
#  'SJ061010': 9.5,
#  'SJ061791': 9.5,
#  'SJ061836': 19.0,
#  'SJ062079': 1.0,
#  'SJ064588': 28.9,
#  'SJ064739': 18.2,
#  'SJ064917': 15.0,
#  'SJ066679': 9.95,
#  'SJ069160': 12.35,
#  'SJ070518': 4.5,
#  'SJ071187': 23.9,
#  'SJ072582': 7.9,
#  'SJ075198': 11.9,
#  'SJ075310': 23.0,
#  'SJ076268': 7.800000000000001,
#  'SJ076702': 15.5,
#  'SJ077247': 29.5,
#  'SJ077475': 23.0,
#  'SJ077534': 10.335,
#  'SJ078443': 9.5,
#  'SJ080497': 29.5,
#  'SJ080736': 29.9,
#  'SJ081657': 9.035,
#  'SJ082363': 29.5,
#  'SJ084890': 25.5,
#  'SJ086830': 18.5,
#  'SJ088277': 15.0,
#  'SJ088818': 16.185,
#  'SJ089386': 5.525,
#  'SJ089920': 28.5,
#  'SJ091660': 24.0,
#  'SJ092560': 8.775,
#  'SJ093375': 15.9,
#  'SJ093462': 18.5,
#  'SJ094390': 28.95,
#  'SJ094434': 27.9,
#  'SJ094446': 5.5,
#  'SJ094535': 28.5,
#  'SJ094902': 15.5,
#  'SJ095439': 2.9,
#  'SJ096513': 14.5,
#  'SJ096805': 14.0,
#  'SJ097045': 12.9,
#  'SJ097332': 9.75,
#  'SJ098118': 16.0,
#  'SJ100081': 5.5,
#  'SJ100125': 21.5,
#  'SJ101131': 24.0,
#  'SJ101492': 2.0,
#  'SJ103138': 25.5,
#  'SJ105836': 16.575,
#  'SJ105935': 10.9,
#  'SJ106685': 2.5935,
#  'SJ108753': 26.0,
#  'SJ109229': 12.0,
#  'SJ109482': 23.5,
#  'SJ111307': 29.5,
#  'SJ112305': 15.925,
#  'SJ113231': 27.5,
#  'SJ113427': 10.95,
#  'SJ113429': 10.0,
#  'SJ114357': 29.0,
#  'SJ114804': 19.9,
#  'SJ115655': 18.5,
#  'SJ115700': 23.5,
#  'SJ116874': 17.485,
#  'SJ117119': 10.075,
#  'SJ118059': 9.0,
#  'SJ118061': 13.5,
#  'SJ118344': 19.9,
#  'SJ118417': 25.9,
#  'SJ119736': 5.9,
#  'SJ123031': 13.95,
#  'SJ123433': 16.5,
#  'SJ124083': 27.95,
#  'SJ125406': 4.5,
#  'SJ125445': 5.5,
#  'SJ125655': 21.9,
#  'SJ126445': 16.0,
#  'SJ126918': 9.685,
#  'SJ127443': 19.9,
#  'SJ127618': 11.9,
#  'SJ127829': 15.5,
#  'SJ128282': 26.5,
#  'SJ129435': 20.95,
#  'SJ129539': 1.9,
#  'SJ132726': 18.5,
#  'SJ133491': 10.5,
#  'SJ133493': 18.0,
#  'SJ133538': 5.5,
#  'SJ133755': 3.5,
#  'SJ134383': 5.5,
#  'SJ136825': 25.0,
#  'SJ137857': 10.9,
#  'SJ138256': 18.5,
#  'SJ140422': 5.525,
#  'SJ141015': 10.9,
#  'SJ141113': 27.9,
#  'SJ141558': 17.0,
#  'SJ145384': 9.9,
#  'SJ145793': 11.375,
#  'SJ145816': 21.5,
#  'SJ146129': 23.5,
#  'SJ146491': 0.99,
#  'SJ146806': 17.0,
#  'SJ148237': 17.5,
#  'SJ149035': 11.0,
#  'SJ149129': 5.785,
#  'SJ151011': 27.5,
#  'SJ151734': 9.5,
#  'SJ151851': 25.5,
#  'SJ152903': 5.99,
#  'SJ152949': 1.0,
#  'SJ153058': 16.185,
#  'SJ154157': 27.0,
#  'SJ154334': 25.5,
#  'SJ154363': 23.5,
#  'SJ154412': 8.9,
#  'SJ155542': 12.95,
#  'SJ156164': 14.9,
#  'SJ157048': 12.5,
#  'SJ157311': 2.5,
#  'SJ157740': 1.5,
#  'SJ157804': 23.9,
#  'SJ158161': 16.8675,
#  'SJ158556': 11.5,
#  'SJ158992': 16.185,
#  'SJ160248': 16.5,
#  'SJ161454': 5.5,
#  'SJ161914': 18.0,
#  'SJ163746': 29.5,
#  'SJ164783': 24.5,
#  'SJ165500': 25.5,
#  'SJ165905': 28.0,
#  'SJ166094': 24.5,
#  'SJ166664': 15.275,
#  'SJ167252': 11.5,
#  'SJ168801': 19.5,
#  'SJ169603': 18.9,
#  'SJ169760': 5.8175,
#  'SJ172638': 22.5,
#  'SJ173437': 9.0935,
#  'SJ173954': 22.5,
#  'SJ175313': 15.0,
#  'SJ175724': 9.0,
#  'SJ176335': 14.885,
#  'SJ178380': 9.0,
#  'SJ178382': 17.5,
#  'SJ178657': 18.9,
#  'SJ179242': 18.5,
#  'SJ179419': 23.95,
#  'SJ179523': 9.0,
#  'SJ179668': 28.0,
#  'SJ180767': 22.9,
#  'SJ181488': 16.5,
#  'SJ182543': 0.9750000000000001,
#  'SJ182748': 25.9,
#  'SJ182775': 4.9,
#  'SJ182858': 20.5,
#  'SJ183332': 1.99,
#  'SJ183841': 3.185,
#  'SJ185523': 74.9,
#  'SJ185531': 27.99,
#  'SJ186328': 10.9,
#  'SJ186436': 18.5,
#  'SJ187666': 27.5,
#  'SJ189417': 4.0,
#  'SJ189447': 27.0,
#  'SJ189785': 10.5,
#  'SJ190636': 27.9,
#  'SJ191263': 7.95,
#  'SJ191272': 1.885,
#  'SJ191644': 11.9,
#  'SJ191661': 24.9,
#  'SJ191665': 4.55,
#  'SJ192064': 15.925,
#  'SJ192349': 29.0,
#  'SJ001173': 17.9,
#  'SJ004246': 18.0,
#  'SJ004724': 12.675,
#  'SJ004794': 26.5,
#  'SJ005275': 7.475000000000001,
#  'SJ005417': 21.9,
#  'SJ005866': 4.485,
#  'SJ007428': 4.0,
#  'SJ007442': 18.95,
#  'SJ007564': 27.0,
#  'SJ008581': 23.9,
#  'SJ009770': 14.95,
#  'SJ010267': 11.5,
#  'SJ010900': 11.0,
#  'SJ010933': 29.9,
#  'SJ011012': 17.875,
#  'SJ012475': 11.05,
#  'SJ013480': 12.5,
#  'SJ014312': 14.9,
#  'SJ014864': 13.975,
#  'SJ015062': 14.9435,
#  'SJ017515': 6.5,
#  'SJ021548': 16.5,
#  'SJ022206': 28.9,
#  'SJ023155': 16.99,
#  'SJ023516': 2.5,
#  'SJ023697': 17.875,
#  'SJ025951': 19.5,
#  'SJ026076': 12.5,
#  'SJ027900': 14.5,
#  'SJ028327': 9.5,
#  'SJ028870': 27.0,
#  'SJ029805': 27.0,
#  'SJ031692': 6.5,
#  'SJ031723': 4.9,
#  'SJ032673': 4.55,
#  'SJ033489': 7.800000000000001,
#  'SJ033583': 24.5,
#  'SJ034896': 7.9,
#  'SJ034919': 23.5,
#  'SJ035244': 14.9,
#  'SJ035674': 10.0,
#  'SJ035996': 27.9,
#  'SJ036015': 18.95,
#  'SJ036717': 3.0,
#  'SJ037663': 11.6935,
#  'SJ038188': 12.5,
#  'SJ038664': 4.5,
#  'SJ039201': 1.9,
#  'SJ039637': 18.785,
#  'SJ039643': 7.0,
#  'SJ039761': 27.5,
#  'SJ040157': 22.5,
#  'SJ040354': 14.99,
#  'SJ044416': 3.9,
#  'SJ045115': 28.5,
#  'SJ045262': 1.5,
#  'SJ045773': 8.125,
#  'SJ046078': 6.175,
#  'SJ047801': 13.0,
#  'SJ048078': 8.5,
#  'SJ052213': 25.0,
#  'SJ052601': 10.0,
#  'SJ053167': 29.9,
#  'SJ054184': 13.9,
#  'SJ054352': 18.9,
#  'SJ054734': 29.5,
#  'SJ057814': 16.9,
#  'SJ057899': 10.0,
#  'SJ058548': 24.5,
#  'SJ059620': 19.5,
#  'SJ059841': 12.675,
#  'SJ061166': 18.5,
#  'SJ063307': 21.0,
#  'SJ064597': 18.785,
#  'SJ067236': 14.0,
#  'SJ067655': 29.9,
#  'SJ068382': 5.135000000000001,
#  'SJ070666': 2.925,
#  'SJ071584': 12.5,
#  'SJ071717': 19.9,
#  'SJ072005': 6.5,
#  'SJ072182': 24.0,
#  'SJ073303': 6.5,
#  'SJ073386': 6.9,
#  'SJ073414': 4.9,
#  'SJ073879': 23.5,
#  'SJ074936': 29.5,
#  'SJ075810': 5.5,
#  'SJ079060': 9.5,
#  'SJ080508': 10.5,
#  'SJ081208': 29.5,
#  'SJ081402': 7.475000000000001,
#  'SJ082970': 19.435,
#  'SJ083687': 9.0,
#  'SJ084261': 13.5,
#  'SJ084268': 1.95,
#  'SJ084532': 22.0,
#  'SJ085337': 5.0,
#  'SJ085543': 6.0,
#  'SJ086626': 5.5,
#  'SJ087567': 21.5,
#  'SJ087693': 0.6174999999999999,
#  'SJ088201': 21.9,
#  'SJ088216': 12.025,
#  'SJ090225': 17.95,
#  'SJ090552': 8.9,
#  'SJ092514': 8.775,
#  'SJ092957': 11.5,
#  'SJ093162': 5.5,
#  'SJ093643': 16.5,
#  'SJ093923': 2.95,
#  'SJ095419': 29.9,
#  'SJ096018': 9.9,
#  'SJ096084': 22.9,
#  'SJ096165': 14.5,
#  'SJ096693': 14.3,
#  'SJ096729': 22.9,
#  'SJ097656': 11.95,
#  'SJ098109': 29.95,
#  'SJ098879': 12.9,
#  'SJ100352': 11.635,
#  'SJ101980': 18.135,
#  'SJ103313': 16.9,
#  'SJ103750': 10.3675,
#  'SJ104202': 12.5,
#  'SJ104536': 15.925,
#  'SJ104904': 11.9,
#  'SJ105033': 7.735,
#  'SJ105258': 9.5,
#  'SJ105608': 10.5,
#  'SJ106818': 5.5,
#  'SJ107632': 6.5,
#  'SJ109344': 9.0,
#  'SJ109477': 7.0,
#  'SJ110179': 19.5,
#  'SJ110328': 28.9,
#  'SJ110920': 6.5,
#  'SJ110943': 19.9,
#  'SJ113216': 13.5,
#  'SJ114467': 14.9,
#  'SJ114754': 5.95,
#  'SJ114757': 9.425,
#  'SJ114775': 3.575,
#  'SJ115001': 13.5,
#  'SJ115293': 5.5,
#  'SJ115297': 15.275,
#  'SJ115930': 12.0,
#  'SJ116257': 14.625,
#  'SJ116771': 2.5,
#  'SJ116845': 1.5,
#  'SJ118818': 6.467499999999999,
#  'SJ120506': 8.0,
#  'SJ121081': 11.0,
#  'SJ122197': 13.0,
#  'SJ122812': 24.5,
#  'SJ124556': 2.0,
#  'SJ124722': 14.0,
#  'SJ124906': 6.5,
#  'SJ125080': 12.0,
#  'SJ125725': 4.0,
#  'SJ125870': 0.9,
#  'SJ125886': 10.5,
#  'SJ126153': 17.99,
#  'SJ127643': 4.0,
#  'SJ128251': 12.675,
#  'SJ128923': 10.0,
#  'SJ130469': 11.5,
#  'SJ132817': 16.5,
#  'SJ133323': 23.9,
#  'SJ133664': 18.0,
#  'SJ135034': 8.0,
#  'SJ135215': 13.6435,
#  'SJ135739': 4.875,
#  'SJ136074': 26.5,
#  'SJ136667': 8.0,
#  'SJ137808': 16.0,
#  'SJ139147': 12.025,
#  'SJ140426': 2.275,
#  'SJ141177': 16.835,
#  'SJ141435': 28.9,
#  'SJ142338': 1.9,
#  'SJ145720': 16.9,
#  'SJ145984': 21.9,
#  'SJ146094': 12.0,
#  'SJ146402': 4.0,
#  'SJ146454': 7.9,
#  'SJ146746': 7.15,
#  'SJ147689': 10.0,
#  'SJ148908': 0.65,
#  'SJ149037': 21.9,
#  'SJ149271': 29.5,
#  ...}

# %% [markdown]
# Q3.4.3. How would you split the ```revenue_per_order``` dictionary into two seperate lists called ```booknrs``` and ```amounts```?

# %% [markdown]
# A3.4.3. You can split the ```revenue_per_order``` dictionary into two seperate list by calling the ```keys()``` and ```values()``` functions, and assigning each to seperate lists.

# %%
booknrs = list(revenue_per_order.keys())[0:3] # Here only showing the first three items
amounts = list(revenue_per_order.values())[0:3] # Here only showing the first three items

print(booknrs, amounts)
# Out:
# ['SJ001027', 'SJ002740', 'SJ003844'] [6.9, 14.885, 17.5]
